# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls
# !rm -fr darknet
# !git clone https://github.com/manugaioni/darknet/
# Out:
# darknet  drive	sample_data
# Cloning into 'darknet'...
# remote: Enumerating objects: 10732, done.
# remote: Total 10732 (delta 0), reused 0 (delta 0), pack-reused 10732
# Receiving objects: 100% (10732/10732), 10.30 MiB | 10.46 MiB/s, done.
# Resolving deltas: 100% (7253/7253), done.

# %%
cp drive/'My Drive'/helmet/data_for_colab.zip /content/darknet

# %%
cd darknet
# Out:
# /content/darknet

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov3.sh*        scripts/
# appveyor.yml  DarknetConfig.cmake.in  include/                src/
# build/        darknet.py              json_mjpeg_streams.sh*  video_v2.sh*
# build.ps1*    darknet_video.py        LICENSE                 video_yolov3.sh*
# build.sh*     data/                   Makefile
# cfg/          data_for_colab.zip      net_cam_v3.sh*
# cmake/        image_yolov2.sh*        README.md

# %%
# !unzip data_for_colab
# Out:
# Archive:  data_for_colab.zip
#    creating: data_for_colab/
#   inflating: data_for_colab/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/data_for_colab/
#   inflating: __MACOSX/data_for_colab/._.DS_Store
#    creating: data_for_colab/data/
#   inflating: data_for_colab/data/.DS_Store
#    creating: __MACOSX/data_for_colab/data/
#   inflating: __MACOSX/data_for_colab/data/._.DS_Store
#   inflating: data_for_colab/data/100.jpg
#   inflating: __MACOSX/data_for_colab/data/._100.jpg
#   inflating: data_for_colab/data/100.txt
#   inflating: data_for_colab/data/101.jpg
#   inflating: __MACOSX/data_for_colab/data/._101.jpg
#   inflating: data_for_colab/data/101.txt
#   inflating: data_for_colab/data/102.jpg
#   inflating: __MACOSX/data_for_colab/data/._102.jpg
#   inflating: data_for_colab/data/102.txt
#   inflating: data_for_colab/data/11.png
#   inflating: __MACOSX/data_for_colab/data/._11.png
#   inflating: data_for_colab/data/11.txt
#   inflating: data_for_colab/data/12.jpg
#   inflating: __MACOSX/data_for_colab/data/._12.jpg
#   inflating: data_for_colab/data/12.txt
#   inflating: data_for_colab/data/13.jpg
#   inflating: __MACOSX/data_for_colab/data/._13.jpg
#   inflating: data_for_colab/data/13.txt
#   inflating: data_for_colab/data/14.jpg
#   inflating: __MACOSX/data_for_colab/data/._14.jpg
#   inflating: data_for_colab/data/14.txt
#   inflating: data_for_colab/data/15.jpg
#   inflating: __MACOSX/data_for_colab/data/._15.jpg
#   inflating: data_for_colab/data/15.txt
#   inflating: data_for_colab/data/16.jpg
#   inflating: __MACOSX/data_for_colab/data/._16.jpg
#   inflating: data_for_colab/data/16.txt
#   inflating: data_for_colab/data/17.jpeg
#   inflating: __MACOSX/data_for_colab/data/._17.jpeg
#   inflating: data_for_colab/data/17.txt
#   inflating: data_for_colab/data/18.jpeg
#   inflating: __MACOSX/data_for_colab/data/._18.jpeg
#   inflating: data_for_colab/data/18.txt
#   inflating: data_for_colab/data/19.jpg
#   inflating: __MACOSX/data_for_colab/data/._19.jpg
#   inflating: data_for_colab/data/19.txt
#   inflating: data_for_colab/data/20.jpg
#   inflating: __MACOSX/data_for_colab/data/._20.jpg
#   inflating: data_for_colab/data/20.txt
#   inflating: data_for_colab/data/21.jpeg
#   inflating: __MACOSX/data_for_colab/data/._21.jpeg
#   inflating: data_for_colab/data/21.txt
#   inflating: data_for_colab/data/22.jpg
#   inflating: __MACOSX/data_for_colab/data/._22.jpg
#   inflating: data_for_colab/data/22.txt
#   inflating: data_for_colab/data/23.jpg
#   inflating: __MACOSX/data_for_colab/data/._23.jpg
#   inflating: data_for_colab/data/23.txt
#   inflating: data_for_colab/data/24.JPG
#   inflating: __MACOSX/data_for_colab/data/._24.JPG
#   inflating: data_for_colab/data/24.txt
#   inflating: data_for_colab/data/25.jpeg
#   inflating: __MACOSX/data_for_colab/data/._25.jpeg
#   inflating: data_for_colab/data/25.txt
#   inflating: data_for_colab/data/26.jpeg
#   inflating: __MACOSX/data_for_colab/data/._26.jpeg
#   inflating: data_for_colab/data/26.txt
#   inflating: data_for_colab/data/27.jpeg
#   inflating: __MACOSX/data_for_colab/data/._27.jpeg
#   inflating: data_for_colab/data/27.txt
#   inflating: data_for_colab/data/28.jpg
#   inflating: __MACOSX/data_for_colab/data/._28.jpg
#   inflating: data_for_colab/data/28.txt
#   inflating: data_for_colab/data/29.jpg
#   inflating: __MACOSX/data_for_colab/data/._29.jpg
#   inflating: data_for_colab/data/29.txt
#   inflating: data_for_colab/data/30.jpg
#   inflating: __MACOSX/data_for_colab/data/._30.jpg
#   inflating: data_for_colab/data/30.txt
#   inflating: data_for_colab/data/31.jpg
#   inflating: __MACOSX/data_for_colab/data/._31.jpg
#   inflating: data_for_colab/data/31.txt
#   inflating: data_for_colab/data/32.jpg
#   inflating: __MACOSX/data_for_colab/data/._32.jpg
#   inflating: data_for_colab/data/32.txt
#   inflating: data_for_colab/data/33.jpg
#   inflating: __MACOSX/data_for_colab/data/._33.jpg
#   inflating: data_for_colab/data/33.txt
#   inflating: data_for_colab/data/34.JPG
#   inflating: __MACOSX/data_for_colab/data/._34.JPG
#   inflating: data_for_colab/data/34.txt
#   inflating: data_for_colab/data/36.jpg
#   inflating: __MACOSX/data_for_colab/data/._36.jpg
#   inflating: data_for_colab/data/36.txt
#   inflating: data_for_colab/data/37.jpg
#   inflating: __MACOSX/data_for_colab/data/._37.jpg
#   inflating: data_for_colab/data/37.txt
#   inflating: data_for_colab/data/39.jpeg
#   inflating: __MACOSX/data_for_colab/data/._39.jpeg
#   inflating: data_for_colab/data/39.txt
#   inflating: data_for_colab/data/40.jpg
#   inflating: __MACOSX/data_for_colab/data/._40.jpg
#   inflating: data_for_colab/data/40.txt
#   inflating: data_for_colab/data/41.jpeg
#   inflating: __MACOSX/data_for_colab/data/._41.jpeg
#   inflating: data_for_colab/data/41.txt
#   inflating: data_for_colab/data/42.jpg
#   inflating: __MACOSX/data_for_colab/data/._42.jpg
#   inflating: data_for_colab/data/42.txt
#   inflating: data_for_colab/data/43.jpg
#   inflating: __MACOSX/data_for_colab/data/._43.jpg
#   inflating: data_for_colab/data/43.txt
#   inflating: data_for_colab/data/44.jpg
#   inflating: __MACOSX/data_for_colab/data/._44.jpg
#   inflating: data_for_colab/data/44.txt
#   inflating: data_for_colab/data/45.jpg
#   inflating: __MACOSX/data_for_colab/data/._45.jpg
#   inflating: data_for_colab/data/45.txt
#   inflating: data_for_colab/data/46.jpg
#   inflating: __MACOSX/data_for_colab/data/._46.jpg
#   inflating: data_for_colab/data/46.txt
#   inflating: data_for_colab/data/47.jpeg
#   inflating: __MACOSX/data_for_colab/data/._47.jpeg
#   inflating: data_for_colab/data/47.txt
#   inflating: data_for_colab/data/48.jpeg
#   inflating: __MACOSX/data_for_colab/data/._48.jpeg
#   inflating: data_for_colab/data/48.txt
#   inflating: data_for_colab/data/49.jpg
#   inflating: __MACOSX/data_for_colab/data/._49.jpg
#   inflating: data_for_colab/data/49.txt
#   inflating: data_for_colab/data/50.jpeg
#   inflating: __MACOSX/data_for_colab/data/._50.jpeg
#   inflating: data_for_colab/data/50.txt
#   inflating: data_for_colab/data/51.jpg
#   inflating: __MACOSX/data_for_colab/data/._51.jpg
#   inflating: data_for_colab/data/51.txt
#   inflating: data_for_colab/data/52.png
#   inflating: __MACOSX/data_for_colab/data/._52.png
#   inflating: data_for_colab/data/52.txt
#   inflating: data_for_colab/data/53.jpg
#   inflating: __MACOSX/data_for_colab/data/._53.jpg
#   inflating: data_for_colab/data/53.txt
#   inflating: data_for_colab/data/54.jpeg
#   inflating: __MACOSX/data_for_colab/data/._54.jpeg
#   inflating: data_for_colab/data/54.txt
#   inflating: data_for_colab/data/56.jpeg
#   inflating: __MACOSX/data_for_colab/data/._56.jpeg
#   inflating: data_for_colab/data/56.txt
#   inflating: data_for_colab/data/57.jpg
#   inflating: __MACOSX/data_for_colab/data/._57.jpg
#   inflating: data_for_colab/data/57.txt
#   inflating: data_for_colab/data/58.jpg
#   inflating: __MACOSX/data_for_colab/data/._58.jpg
#   inflating: data_for_colab/data/58.txt
#   inflating: data_for_colab/data/59.jpg
#   inflating: __MACOSX/data_for_colab/data/._59.jpg
#   inflating: data_for_colab/data/59.txt
#   inflating: data_for_colab/data/60.jpg
#   inflating: __MACOSX/data_for_colab/data/._60.jpg
#   inflating: data_for_colab/data/60.txt
#   inflating: data_for_colab/data/61.jpg
#   inflating: __MACOSX/data_for_colab/data/._61.jpg
#   inflating: data_for_colab/data/61.txt
#   inflating: data_for_colab/data/62.jpeg
#   inflating: __MACOSX/data_for_colab/data/._62.jpeg
#   inflating: data_for_colab/data/62.txt
#   inflating: data_for_colab/data/63.jpeg
#   inflating: __MACOSX/data_for_colab/data/._63.jpeg
#   inflating: data_for_colab/data/63.txt
#   inflating: data_for_colab/data/64.jpg
#   inflating: __MACOSX/data_for_colab/data/._64.jpg
#   inflating: data_for_colab/data/64.txt
#   inflating: data_for_colab/data/65.jpg
#   inflating: __MACOSX/data_for_colab/data/._65.jpg
#   inflating: data_for_colab/data/65.txt
#   inflating: data_for_colab/data/66.jpg
#   inflating: __MACOSX/data_for_colab/data/._66.jpg
#   inflating: data_for_colab/data/66.txt
#   inflating: data_for_colab/data/67.jpg
#   inflating: __MACOSX/data_for_colab/data/._67.jpg
#   inflating: data_for_colab/data/67.txt
#   inflating: data_for_colab/data/68.jpg
#   inflating: __MACOSX/data_for_colab/data/._68.jpg
#   inflating: data_for_colab/data/68.txt
#   inflating: data_for_colab/data/69.jpg
#   inflating: __MACOSX/data_for_colab/data/._69.jpg
#   inflating: data_for_colab/data/69.txt
#   inflating: data_for_colab/data/70.jpg
#   inflating: __MACOSX/data_for_colab/data/._70.jpg
#   inflating: data_for_colab/data/70.txt
#   inflating: data_for_colab/data/72.jpg
#   inflating: __MACOSX/data_for_colab/data/._72.jpg
#   inflating: data_for_colab/data/72.txt
#   inflating: data_for_colab/data/73.jpg
#   inflating: __MACOSX/data_for_colab/data/._73.jpg
#   inflating: data_for_colab/data/73.txt
#   inflating: data_for_colab/data/74.jpg
#   inflating: __MACOSX/data_for_colab/data/._74.jpg
#   inflating: data_for_colab/data/74.txt
#   inflating: data_for_colab/data/75.jpg
#   inflating: __MACOSX/data_for_colab/data/._75.jpg
#   inflating: data_for_colab/data/75.txt
#   inflating: data_for_colab/data/76.jpg
#   inflating: __MACOSX/data_for_colab/data/._76.jpg
#   inflating: data_for_colab/data/76.txt
#   inflating: data_for_colab/data/77.jpg
#   inflating: __MACOSX/data_for_colab/data/._77.jpg
#   inflating: data_for_colab/data/77.txt
#   inflating: data_for_colab/data/78.jpg
#   inflating: __MACOSX/data_for_colab/data/._78.jpg
#   inflating: data_for_colab/data/78.txt
#   inflating: data_for_colab/data/79.jpeg
#   inflating: __MACOSX/data_for_colab/data/._79.jpeg
#   inflating: data_for_colab/data/79.txt
#   inflating: data_for_colab/data/80.jpg
#   inflating: __MACOSX/data_for_colab/data/._80.jpg
#   inflating: data_for_colab/data/80.txt
#   inflating: data_for_colab/data/81.jpg
#   inflating: __MACOSX/data_for_colab/data/._81.jpg
#   inflating: data_for_colab/data/81.txt
#   inflating: data_for_colab/data/82.jpg
#   inflating: __MACOSX/data_for_colab/data/._82.jpg
#   inflating: data_for_colab/data/82.txt
#   inflating: data_for_colab/data/83.jpeg
#   inflating: __MACOSX/data_for_colab/data/._83.jpeg
#   inflating: data_for_colab/data/83.txt
#   inflating: data_for_colab/data/84.jpeg
#   inflating: __MACOSX/data_for_colab/data/._84.jpeg
#   inflating: data_for_colab/data/84.txt
#   inflating: data_for_colab/data/85.jpg
#   inflating: __MACOSX/data_for_colab/data/._85.jpg
#   inflating: data_for_colab/data/85.txt
#   inflating: data_for_colab/data/86.jpg
#   inflating: __MACOSX/data_for_colab/data/._86.jpg
#   inflating: data_for_colab/data/86.txt
#   inflating: data_for_colab/data/87.jpg
#   inflating: __MACOSX/data_for_colab/data/._87.jpg
#   inflating: data_for_colab/data/87.txt
#   inflating: data_for_colab/data/88.jpeg
#   inflating: __MACOSX/data_for_colab/data/._88.jpeg
#   inflating: data_for_colab/data/88.txt
#   inflating: data_for_colab/data/89.jpg
#   inflating: __MACOSX/data_for_colab/data/._89.jpg
#   inflating: data_for_colab/data/89.txt
#   inflating: data_for_colab/data/90.jpg
#   inflating: __MACOSX/data_for_colab/data/._90.jpg
#   inflating: data_for_colab/data/90.txt
#   inflating: data_for_colab/data/91.jpg
#   inflating: __MACOSX/data_for_colab/data/._91.jpg
#   inflating: data_for_colab/data/91.txt
#   inflating: data_for_colab/data/92.jpg
#   inflating: __MACOSX/data_for_colab/data/._92.jpg
#   inflating: data_for_colab/data/92.txt
#   inflating: data_for_colab/data/93.jpg
#   inflating: __MACOSX/data_for_colab/data/._93.jpg
#   inflating: data_for_colab/data/93.txt
#   inflating: data_for_colab/data/94.jpg
#   inflating: __MACOSX/data_for_colab/data/._94.jpg
#   inflating: data_for_colab/data/94.txt
#   inflating: data_for_colab/data/95.jpg
#   inflating: __MACOSX/data_for_colab/data/._95.jpg
#   inflating: data_for_colab/data/95.txt
#   inflating: data_for_colab/data/96.jpg
#   inflating: __MACOSX/data_for_colab/data/._96.jpg
#   inflating: data_for_colab/data/96.txt
#   inflating: data_for_colab/data/97.jpg
#   inflating: __MACOSX/data_for_colab/data/._97.jpg
#   inflating: data_for_colab/data/97.txt
#   inflating: data_for_colab/data/98.jpg
#   inflating: __MACOSX/data_for_colab/data/._98.jpg
#   inflating: data_for_colab/data/98.txt
#   inflating: data_for_colab/data/99.jpg
#   inflating: __MACOSX/data_for_colab/data/._99.jpg
#   inflating: data_for_colab/data/99.txt
#   inflating: data_for_colab/data/eight.jpg
#   inflating: __MACOSX/data_for_colab/data/._eight.jpg
#   inflating: data_for_colab/data/eight.txt
#   inflating: data_for_colab/data/five.jpeg
#   inflating: __MACOSX/data_for_colab/data/._five.jpeg
#   inflating: data_for_colab/data/five.txt
#   inflating: data_for_colab/data/four.jpeg
#   inflating: __MACOSX/data_for_colab/data/._four.jpeg
#   inflating: data_for_colab/data/four.txt
#   inflating: data_for_colab/data/nine.jpg
#   inflating: __MACOSX/data_for_colab/data/._nine.jpg
#   inflating: data_for_colab/data/nine.txt
#   inflating: data_for_colab/data/road.jpg
#   inflating: __MACOSX/data_for_colab/data/._road.jpg
#   inflating: data_for_colab/data/road.txt
#   inflating: data_for_colab/data/seven.jpg
#   inflating: __MACOSX/data_for_colab/data/._seven.jpg
#   inflating: data_for_colab/data/seven.txt
#   inflating: data_for_colab/data/si.jpeg
#   inflating: __MACOSX/data_for_colab/data/._si.jpeg
#   inflating: data_for_colab/data/si.txt
#   inflating: data_for_colab/data/ten.jpeg
#   inflating: __MACOSX/data_for_colab/data/._ten.jpeg
#   inflating: data_for_colab/data/ten.txt
#   inflating: data_for_colab/data/three.jpeg
#   inflating: __MACOSX/data_for_colab/data/._three.jpeg
#   inflating: data_for_colab/data/three.txt
#   inflating: data_for_colab/data/two.jpg
#   inflating: __MACOSX/data_for_colab/data/._two.jpg
#   inflating: data_for_colab/data/two.txt
#   inflating: data_for_colab/obj.data
#   inflating: __MACOSX/data_for_colab/._obj.data
#   inflating: data_for_colab/obj.names
#   inflating: __MACOSX/data_for_colab/._obj.names
#   inflating: data_for_colab/test.txt
#   inflating: data_for_colab/train.txt
#   inflating: data_for_colab/yolov3-tiny-obj.cfg
#   inflating: data_for_colab/yolov3-tiny.conv.15

# %%
#upload train test.txt files
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
#      <input type="file" id="files-839fecbd-65fd-40ea-a805-f23825a573b8" name="files[]" multiple disabled />
#      <output id="result-839fecbd-65fd-40ea-a805-f23825a573b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.txt to test.txt
# Saving train.txt to train.txt
# saved file test.txt
# saved file train.txt

# %%
# !apt-get update
# !apt-get upgrade
# Out:
# Get:1 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Get:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [819 B]
# Get:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [29.0 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,677 kB]
# Get:16 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [805 kB]
# Get:17 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [67.6 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [4,173 B]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [612 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [6,222 B]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [747 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [7,216 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [921 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [16.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,274 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [4,212 B]
# Get:27 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [103 kB]
# Get:28 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [12.3 kB]
# Fetched 6,582 kB in 2s (2,959 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following packages have been kept back:
#   cuda-drivers libcudnn7 libcudnn7-dev libnccl-dev libnccl2 libnvidia-cfg1-418
#   libnvidia-common-418 libnvidia-compute-418 libnvidia-decode-418
#   libnvidia-encode-418 libnvidia-fbc1-418 libnvidia-gl-418 libnvidia-ifr1-418
#   linux-headers-generic nvidia-compute-utils-418 nvidia-dkms-418
#   nvidia-driver-418 nvidia-kernel-common-418 nvidia-kernel-source-418
#   nvidia-utils-418 xserver-xorg-video-nvidia-418
# The following packages will be upgraded:
#   base-files cmake cmake-data dkms libegl-mesa0 libegl1-mesa-dev libgbm1
#   libgl1-mesa-dev libgl1-mesa-dri libglapi-mesa libgles2-mesa-dev libglx-mesa0
#   libinput-bin libinput10 libldap-2.4-2 libldap-common libpam-systemd
#   libpoppler73 libpq5 libsystemd0 libudev1 libxnvctrl0 linux-libc-dev
#   mesa-common-dev nvidia-modprobe nvidia-settings openjdk-11-jre
#   openjdk-11-jre-headless openjdk-8-jdk-headless openjdk-8-jre-headless
#   python3-software-properties r-cran-boot r-cran-cluster r-cran-foreign
#   r-cran-ggplot2 r-cran-httr r-cran-knitr r-cran-markdown r-cran-mgcv
#   r-cran-modelr r-cran-nlme r-cran-pkgbuild r-cran-tinytex r-cran-xml2
#   software-properties-common systemd systemd-sysv udev
# 48 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Need to get 106 MB of archives.
# After this operation, 1,587 kB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-foreign amd64 0.8.72-1ppabionic0 [233 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 base-files amd64 10.1ubuntu2.6 [60.1 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-cran-boot 1.3-23-2bionic0 [618 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libxnvctrl0 418.87.00-0ubuntu1 [19.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd-sysv amd64 237-3ubuntu10.25 [11.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-systemd amd64 237-3ubuntu10.25 [108 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-settings 418.87.00-0ubuntu1 [966 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsystemd0 amd64 237-3ubuntu10.25 [204 kB]
# Get:9 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-nlme amd64 3.1.141-1ppabionic0 [2,238 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd amd64 237-3ubuntu10.25 [2,903 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-cran-cluster 2.1.0-2bionic0 [527 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-modprobe 418.87.00-0ubuntu1 [19.2 kB]
# Get:13 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-cran-mgcv 1.8-28-2bionic0 [2,638 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 udev amd64 237-3ubuntu10.25 [1,101 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-ggplot2 all 3.2.1-1cran1ppabionic0 [3,773 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev1 amd64 237-3ubuntu10.25 [53.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 cmake amd64 3.10.2-1ubuntu2.18.04.1 [3,152 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 cmake-data all 3.10.2-1ubuntu2.18.04.1 [1,332 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dkms all 2.3-3ubuntu9.5 [68.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl-mesa0 amd64 19.0.8-0ubuntu0~18.04.1 [99.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgbm1 amd64 19.0.8-0ubuntu0~18.04.1 [27.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dri amd64 19.0.8-0ubuntu0~18.04.1 [7,499 kB]
# Get:23 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-httr all 1.4.1-1cran1ppabionic0 [470 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx-mesa0 amd64 19.0.8-0ubuntu0~18.04.1 [141 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglapi-mesa amd64 19.0.8-0ubuntu0~18.04.1 [25.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dev amd64 19.0.8-0ubuntu0~18.04.1 [6,044 B]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl1-mesa-dev amd64 19.0.8-0ubuntu0~18.04.1 [19.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-common-dev amd64 19.0.8-0ubuntu0~18.04.1 [602 kB]
# Get:29 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-markdown amd64 1.1-1cran1ppabionic0 [117 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles2-mesa-dev amd64 19.0.8-0ubuntu0~18.04.1 [43.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libinput-bin amd64 1.10.4-1ubuntu0.18.04.1 [11.1 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libinput10 amd64 1.10.4-1ubuntu0.18.04.1 [86.1 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.3 [16.9 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.3 [155 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler73 amd64 0.62.0-2ubuntu2.10 [800 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpq5 amd64 10.10-0ubuntu0.18.04.1 [108 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-58.64 [1,043 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre amd64 11.0.4+11-1ubuntu2~18.04.3 [34.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre-headless amd64 11.0.4+11-1ubuntu2~18.04.3 [37.4 MB]
# Get:40 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-knitr all 1.24-1cran1ppabionic0 [1,161 kB]
# Get:41 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-modelr all 0.1.5-1cran1ppabionic0 [200 kB]
# Get:42 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-pkgbuild all 1.0.4-1cran1ppabionic0 [130 kB]
# Get:43 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-tinytex all 0.15-1cran1ppabionic0 [97.3 kB]
# Get:44 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-xml2 amd64 1.2.2-1cran1ppabionic0 [293 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk-headless amd64 8u222-b10-1ubuntu1~18.04.1 [8,267 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u222-b10-1ubuntu1~18.04.1 [27.4 MB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 software-properties-common all 0.96.24.32.11 [9,996 B]
# Get:48 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-software-properties all 0.96.24.32.11 [23.6 kB]
# Fetched 106 MB in 2s (68.3 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../base-files_10.1ubuntu2.6_amd64.deb ...
# Unpacking base-files (10.1ubuntu2.6) over (10.1ubuntu2.5) ...
# Setting up base-files (10.1ubuntu2.6) ...
# Installing new version of config file /etc/issue ...
# Installing new version of config file /etc/issue.net ...
# Installing new version of config file /etc/lsb-release ...
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../systemd-sysv_237-3ubuntu10.25_amd64.deb ...
# Unpacking systemd-sysv (237-3ubuntu10.25) over (237-3ubuntu10.24) ...
# Preparing to unpack .../libpam-systemd_237-3ubuntu10.25_amd64.deb ...
# Unpacking libpam-systemd:amd64 (237-3ubuntu10.25) over (237-3ubuntu10.24) ...
# Preparing to unpack .../libsystemd0_237-3ubuntu10.25_amd64.deb ...
# Unpacking libsystemd0:amd64 (237-3ubuntu10.25) over (237-3ubuntu10.24) ...
# Setting up libsystemd0:amd64 (237-3ubuntu10.25) ...
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../systemd_237-3ubuntu10.25_amd64.deb ...
# Unpacking systemd (237-3ubuntu10.25) over (237-3ubuntu10.24) ...
# Preparing to unpack .../udev_237-3ubuntu10.25_amd64.deb ...
# Unpacking udev (237-3ubuntu10.25) over (237-3ubuntu10.24) ...
# Preparing to unpack .../libudev1_237-3ubuntu10.25_amd64.deb ...
# Unpacking libudev1:amd64 (237-3ubuntu10.25) over (237-3ubuntu10.24) ...
# Setting up libudev1:amd64 (237-3ubuntu10.25) ...
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../00-cmake_3.10.2-1ubuntu2.18.04.1_amd64.deb ...
# Unpacking cmake (3.10.2-1ubuntu2.18.04.1) over (3.10.2-1ubuntu2) ...
# Preparing to unpack .../01-cmake-data_3.10.2-1ubuntu2.18.04.1_all.deb ...
# Unpacking cmake-data (3.10.2-1ubuntu2.18.04.1) over (3.10.2-1ubuntu2) ...
# Preparing to unpack .../02-dkms_2.3-3ubuntu9.5_all.deb ...
# Unpacking dkms (2.3-3ubuntu9.5) over (2.3-3ubuntu9.4) ...
# Preparing to unpack .../03-libegl-mesa0_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../04-libgbm1_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libgbm1:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../05-libgl1-mesa-dri_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../06-libglx-mesa0_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../07-libglapi-mesa_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../08-libgl1-mesa-dev_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../09-libegl1-mesa-dev_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../10-mesa-common-dev_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../11-libgles2-mesa-dev_19.0.8-0ubuntu0~18.04.1_amd64.deb ...
# Unpacking libgles2-mesa-dev:amd64 (19.0.8-0ubuntu0~18.04.1) over (19.0.2-1ubuntu1.1~18.04.2) ...
# Preparing to unpack .../12-libinput-bin_1.10.4-1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libinput-bin (1.10.4-1ubuntu0.18.04.1) over (1.10.4-1) ...
# Preparing to unpack .../13-libinput10_1.10.4-1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libinput10:amd64 (1.10.4-1ubuntu0.18.04.1) over (1.10.4-1) ...
# Preparing to unpack .../14-libldap-common_2.4.45+dfsg-1ubuntu1.3_all.deb ...
# Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.3) over (2.4.45+dfsg-1ubuntu1.2) ...
# Preparing to unpack .../15-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.3_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.3) over (2.4.45+dfsg-1ubuntu1.2) ...
# Preparing to unpack .../16-libpoppler73_0.62.0-2ubuntu2.10_amd64.deb ...
# Unpacking libpoppler73:amd64 (0.62.0-2ubuntu2.10) over (0.62.0-2ubuntu2.9) ...
# Preparing to unpack .../17-libpq5_10.10-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libpq5:amd64 (10.10-0ubuntu0.18.04.1) over (10.9-0ubuntu0.18.04.1) ...
# Preparing to unpack .../18-libxnvctrl0_418.87.00-0ubuntu1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (418.87.00-0ubuntu1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../19-linux-libc-dev_4.15.0-58.64_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-58.64) over (4.15.0-55.60) ...
# Preparing to unpack .../20-nvidia-settings_418.87.00-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (418.87.00-0ubuntu1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../21-openjdk-11-jre_11.0.4+11-1ubuntu2~18.04.3_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.4+11-1ubuntu2~18.04.3) over (11.0.3+7-1ubuntu2~18.04.1) ...
# Preparing to unpack .../22-openjdk-11-jre-headless_11.0.4+11-1ubuntu2~18.04.3_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.4+11-1ubuntu2~18.04.3) over (11.0.3+7-1ubuntu2~18.04.1) ...
# Preparing to unpack .../23-openjdk-8-jdk-headless_8u222-b10-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u222-b10-1ubuntu1~18.04.1) over (8u212-b03-0ubuntu1.18.04.1) ...
# Preparing to unpack .../24-openjdk-8-jre-headless_8u222-b10-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u222-b10-1ubuntu1~18.04.1) over (8u212-b03-0ubuntu1.18.04.1) ...
# Preparing to unpack .../25-software-properties-common_0.96.24.32.11_all.deb ...
# Unpacking software-properties-common (0.96.24.32.11) over (0.96.24.32.9) ...
# Preparing to unpack .../26-python3-software-properties_0.96.24.32.11_all.deb ...
# Unpacking python3-software-properties (0.96.24.32.11) over (0.96.24.32.9) ...
# Preparing to unpack .../27-r-cran-boot_1.3-23-2bionic0_all.deb ...
# Unpacking r-cran-boot (1.3-23-2bionic0) over (1.3-23-1cran1ppabionic0) ...
# Preparing to unpack .../28-r-cran-cluster_2.1.0-2bionic0_amd64.deb ...
# Unpacking r-cran-cluster (2.1.0-2bionic0) over (2.1.0-1bionic0) ...
# Preparing to unpack .../29-r-cran-foreign_0.8.72-1ppabionic0_amd64.deb ...
# Unpacking r-cran-foreign (0.8.72-1ppabionic0) over (0.8.71-3cranppa0bionic0) ...
# Preparing to unpack .../30-r-cran-nlme_3.1.141-1ppabionic0_amd64.deb ...
# Unpacking r-cran-nlme (3.1.141-1ppabionic0) over (3.1.140-1ppabionic0) ...
# Preparing to unpack .../31-r-cran-mgcv_1.8-28-2bionic0_amd64.deb ...
# Unpacking r-cran-mgcv (1.8-28-2bionic0) over (1.8-28-1cran1ppabionic0) ...
# Preparing to unpack .../32-r-cran-ggplot2_3.2.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-ggplot2 (3.2.1-1cran1ppabionic0) over (3.2.0-1cran1ppabionic0) ...
# Preparing to unpack .../33-r-cran-httr_1.4.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-httr (1.4.1-1cran1ppabionic0) over (1.4.0-1cran1ppabionic0) ...
# Preparing to unpack .../34-r-cran-markdown_1.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-markdown (1.1-1cran1ppabionic0) over (1.0-1cran1~ubuntu18.04.1~ppa1) ...
# Preparing to unpack .../35-r-cran-knitr_1.24-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-knitr (1.24-1cran1ppabionic0) over (1.23-1cran1ppabionic0) ...
# Preparing to unpack .../36-r-cran-modelr_0.1.5-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-modelr (0.1.5-1cran1ppabionic0) over (0.1.4-1cran1ppabionic0) ...
# Preparing to unpack .../37-r-cran-pkgbuild_1.0.4-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-pkgbuild (1.0.4-1cran1ppabionic0) over (1.0.3-1cran1ppabionic0) ...
# Preparing to unpack .../38-r-cran-tinytex_0.15-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-tinytex (0.15-1cran1ppabionic0) over (0.14-1cran1ppabionic0) ...
# Preparing to unpack .../39-r-cran-xml2_1.2.2-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-xml2 (1.2.2-1cran1ppabionic0) over (1.2.1-1cran1ppabionic0) ...
# Preparing to unpack .../40-nvidia-modprobe_418.87.00-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (418.87.00-0ubuntu1) over (418.67-0ubuntu1) ...
# Setting up r-cran-tinytex (0.15-1cran1ppabionic0) ...
# Setting up r-cran-boot (1.3-23-2bionic0) ...
# Setting up mesa-common-dev:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up libldap-common (2.4.45+dfsg-1ubuntu1.3) ...
# Setting up r-cran-nlme (3.1.141-1ppabionic0) ...
# Setting up libgbm1:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up r-cran-foreign (0.8.72-1ppabionic0) ...
# Setting up linux-libc-dev:amd64 (4.15.0-58.64) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.4+11-1ubuntu2~18.04.3) ...
# Installing new version of config file /etc/java-11-openjdk/security/default.policy ...
# Installing new version of config file /etc/java-11-openjdk/security/public_suffix_list.dat ...
# Setting up cmake-data (3.10.2-1ubuntu2.18.04.1) ...
# Setting up libglapi-mesa:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up libinput-bin (1.10.4-1ubuntu0.18.04.1) ...
# Setting up r-cran-markdown (1.1-1cran1ppabionic0) ...
# Setting up r-cran-modelr (0.1.5-1cran1ppabionic0) ...
# Setting up libpoppler73:amd64 (0.62.0-2ubuntu2.10) ...
# Setting up libgl1-mesa-dev:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up dkms (2.3-3ubuntu9.5) ...
# Setting up r-cran-mgcv (1.8-28-2bionic0) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up udev (237-3ubuntu10.25) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.3) ...
# Setting up systemd (237-3ubuntu10.25) ...
# Setting up libegl1-mesa-dev:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up nvidia-modprobe (418.87.00-0ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up python3-software-properties (0.96.24.32.11) ...
# Setting up r-cran-ggplot2 (3.2.1-1cran1ppabionic0) ...
# Setting up libegl-mesa0:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.1) ...
# Setting up r-cran-xml2 (1.2.2-1cran1ppabionic0) ...
# Setting up cmake (3.10.2-1ubuntu2.18.04.1) ...
# Setting up r-cran-pkgbuild (1.0.4-1cran1ppabionic0) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up libxnvctrl0:amd64 (418.87.00-0ubuntu1) ...
# Setting up r-cran-httr (1.4.1-1cran1ppabionic0) ...
# Setting up r-cran-cluster (2.1.0-2bionic0) ...
# Setting up openjdk-8-jre-headless:amd64 (8u222-b10-1ubuntu1~18.04.1) ...
# Setting up openjdk-11-jre:amd64 (11.0.4+11-1ubuntu2~18.04.3) ...
# Setting up software-properties-common (0.96.24.32.11) ...
# Setting up openjdk-8-jdk-headless:amd64 (8u222-b10-1ubuntu1~18.04.1) ...
# Setting up systemd-sysv (237-3ubuntu10.25) ...
# Setting up r-cran-knitr (1.24-1cran1ppabionic0) ...
# Setting up libgles2-mesa-dev:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up libinput10:amd64 (1.10.4-1ubuntu0.18.04.1) ...
# Setting up libgl1-mesa-dri:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up nvidia-settings (418.87.00-0ubuntu1) ...
# Setting up libpq5:amd64 (10.10-0ubuntu0.18.04.1) ...
# Setting up libglx-mesa0:amd64 (19.0.8-0ubuntu0~18.04.1) ...
# Setting up libpam-systemd:amd64 (237-3ubuntu10.25) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.4).
# libavcodec-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libswscale-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libgail-common libgail18 libgdk-pixbuf2.0-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libmagic-mgc libmagic1 libmail-sendmail-perl
#   libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev libsigsegv2
#   libsys-hostname-long-perl libtimedate-perl libtool libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxml2-utils libxrandr-dev
#   m4 po-debconf x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev libcairo2-doc gvfs libgtk2.0-doc
#   imagemagick libpango1.0-doc libtool-doc gcj-jdk m4-doc libmail-box-perl
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libgail-common libgail18 libgdk-pixbuf2.0-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgtk2.0-dev libmagic-mgc libmagic1 libmail-sendmail-perl
#   libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev libsigsegv2
#   libsys-hostname-long-perl libtimedate-perl libtool libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxml2-utils libxrandr-dev
#   m4 po-debconf x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# 0 upgraded, 50 newly installed, 0 to remove and 21 not upgraded.
# Need to get 11.1 MB of archives.
# After this operation, 56.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.2 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.2 [68.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.2 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.2 [35.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Fetched 11.1 MB in 0s (36.2 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 131294 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.2_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.2) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.2_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.2) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.2_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.2) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../20-gir1.2-atk-1.0_2.28.1-1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../21-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../22-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../23-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../24-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../25-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../26-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package gir1.2-gtk-2.0.
# Preparing to unpack .../27-gir1.2-gtk-2.0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../28-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../29-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../30-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../31-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../32-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../33-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../34-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../35-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../36-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../37-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../38-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../39-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../40-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../41-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../42-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../43-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../44-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../45-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../46-libxml2-utils_2.9.4+dfsg1-6.1ubuntu1.2_amd64.deb ...
# Unpacking libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.2) ...
# Selecting previously unselected package libgtk2.0-dev.
# Preparing to unpack .../47-libgtk2.0-dev_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../48-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../49-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.2) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.2) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.2) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Setting up dh-autoreconf (17) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %%
# !apt-get install vim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libgpm2 vim-common vim-runtime xxd
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 vim vim-common vim-runtime xxd
# 0 upgraded, 5 newly installed, 0 to remove and 21 not upgraded.
# Need to get 6,721 kB of archives.
# After this operation, 32.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xxd amd64 2:8.0.1453-1ubuntu1.1 [49.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-common all 2:8.0.1453-1ubuntu1.1 [70.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgpm2 amd64 1.20.7-5 [15.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-runtime all 2:8.0.1453-1ubuntu1.1 [5,435 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim amd64 2:8.0.1453-1ubuntu1.1 [1,152 kB]
# Fetched 6,721 kB in 0s (36.3 MB/s)
# Selecting previously unselected package xxd.
# (Reading database ... 133340 files and directories currently installed.)
# Preparing to unpack .../xxd_2%3a8.0.1453-1ubuntu1.1_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1.1) ...
# Selecting previously unselected package vim-common.
# Preparing to unpack .../vim-common_2%3a8.0.1453-1ubuntu1.1_all.deb ...
# Unpacking vim-common (2:8.0.1453-1ubuntu1.1) ...
# Selecting previously unselected package libgpm2:amd64.
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package vim-runtime.
# Preparing to unpack .../vim-runtime_2%3a8.0.1453-1ubuntu1.1_all.deb ...
# Adding 'diversion of /usr/share/vim/vim80/doc/help.txt to /usr/share/vim/vim80/doc/help.txt.vim-tiny by vim-runtime'
# Adding 'diversion of /usr/share/vim/vim80/doc/tags to /usr/share/vim/vim80/doc/tags.vim-tiny by vim-runtime'
# Unpacking vim-runtime (2:8.0.1453-1ubuntu1.1) ...
# Selecting previously unselected package vim.
# Preparing to unpack .../vim_2%3a8.0.1453-1ubuntu1.1_amd64.deb ...
# Unpacking vim (2:8.0.1453-1ubuntu1.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up xxd (2:8.0.1453-1ubuntu1.1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up vim-common (2:8.0.1453-1ubuntu1.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up vim-runtime (2:8.0.1453-1ubuntu1.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up vim (2:8.0.1453-1ubuntu1.1) ...
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vim (vim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vimdiff (vimdiff) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rvim (rvim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rview (rview) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vi (vi) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/view (view) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/ex (ex) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/editor (editor) in auto mode

# %%
ls
# Out:
# 3rdparty/               darknet_video.py        Makefile
# appveyor.yml            data/                   net_cam_v3.sh*
# build/                  data_for_colab/         README.md
# build.ps1*              data_for_colab.zip      scripts/
# build.sh*               image_yolov2.sh*        src/
# cfg/                    image_yolov3.sh*        test.txt
# cmake/                  include/                train.txt
# CMakeLists.txt          json_mjpeg_streams.sh*  video_v2.sh*
# DarknetConfig.cmake.in  LICENSE                 video_yolov3.sh*
# darknet.py              __MACOSX/

# %%
#Now let's get some YOLOv3 weights from the official site
# !ls
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       src
# appveyor.yml	darknet.py		json_mjpeg_streams.sh  test.txt
# build		darknet_video.py	LICENSE		       train.txt
# build.ps1	data			__MACOSX	       video_v2.sh
# build.sh	data_for_colab		Makefile	       video_yolov3.sh
# cfg		data_for_colab.zip	net_cam_v3.sh
# cmake		image_yolov2.sh		README.md
# CMakeLists.txt	image_yolov3.sh		scripts
# --2019-08-19 06:55:00--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  13.9MB/s    in 15s
#
# 2019-08-19 06:55:16 (16.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
#No here we're modifying the makefile to set OPENCV and GPU to 1
# !ls
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       src
# appveyor.yml	darknet.py		json_mjpeg_streams.sh  test.txt
# build		darknet_video.py	LICENSE		       train.txt
# build.ps1	data			__MACOSX	       video_v2.sh
# build.sh	data_for_colab		Makefile	       video_yolov3.sh
# cfg		data_for_colab.zip	net_cam_v3.sh	       yolov3.weights
# cmake		image_yolov2.sh		README.md
# CMakeLists.txt	image_yolov3.sh		scripts

# %%
# !ls
# %cd ../
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       src
# appveyor.yml	darknet.py		json_mjpeg_streams.sh  test.txt
# build		darknet_video.py	LICENSE		       train.txt
# build.ps1	data			__MACOSX	       video_v2.sh
# build.sh	data_for_colab		Makefile	       video_yolov3.sh
# cfg		data_for_colab.zip	net_cam_v3.sh	       yolov3.weights
# cmake		image_yolov2.sh		README.md
# CMakeLists.txt	image_yolov3.sh		scripts
# /content
# darknet  drive	sample_data

# %%
# !apt install g++-5
# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 21 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libisl15 amd64 0.18-4 [548 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cpp-5 amd64 5.5.0-12ubuntu1 [7,785 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libasan2 amd64 5.5.0-12ubuntu1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpx0 amd64 5.5.0-12ubuntu1 [9,888 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgcc-5-dev amd64 5.5.0-12ubuntu1 [2,224 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5 amd64 5.5.0-12ubuntu1 [8,357 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libstdc++-5-dev amd64 5.5.0-12ubuntu1 [1,415 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 g++-5 amd64 5.5.0-12ubuntu1 [8,450 kB]
# Fetched 29.1 MB in 1s (49.3 MB/s)
# Selecting previously unselected package gcc-5-base:amd64.
# (Reading database ... 135183 files and directories currently installed.)
# Preparing to unpack .../0-gcc-5-base_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libisl15:amd64.
# Preparing to unpack .../1-libisl15_0.18-4_amd64.deb ...
# Unpacking libisl15:amd64 (0.18-4) ...
# Selecting previously unselected package cpp-5.
# Preparing to unpack .../2-cpp-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking cpp-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libasan2:amd64.
# Preparing to unpack .../3-libasan2_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libasan2:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libmpx0:amd64.
# Preparing to unpack .../4-libmpx0_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libgcc-5-dev:amd64.
# Preparing to unpack .../5-libgcc-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package gcc-5.
# Preparing to unpack .../6-gcc-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libstdc++-5-dev:amd64.
# Preparing to unpack .../7-libstdc++-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package g++-5.
# Preparing to unpack .../8-g++-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking g++-5 (5.5.0-12ubuntu1) ...
# Setting up libisl15:amd64 (0.18-4) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Setting up libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Setting up libasan2:amd64 (5.5.0-12ubuntu1) ...
# Setting up libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up cpp-5 (5.5.0-12ubuntu1) ...
# Setting up libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up gcc-5 (5.5.0-12ubuntu1) ...
# Setting up g++-5 (5.5.0-12ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# update-alternatives: using /usr/bin/gcc-5 to provide /usr/bin/gcc (gcc) in auto mode
# update-alternatives: using /usr/bin/g++-5 to provide /usr/bin/g++ (g++) in auto mode

# %%
#Now, here's a bunch of code that takes the longest to execute here but
#It's about installing CUDA and using the beautiful Tesla K80 GPU, so that
#Will worth it

# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y
# Out:
# 21 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2019-08-19 06:56:23--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.182.215
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.182.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?Ot-oKd58tap83Nx4_8xZdQ85VlamSAwHQIV13GTVfI9CmQK19VqIZobvbVZO0Ar091OVdcyJ-_TNEHG0Zts8dQDt_QkOHe7VwCmPhspHdTXgCybsnnCe7_KL4sY5fxM7f9SjP7am99tiA7hVJP6izlMMdJoRmMcfAQ-ZXiCeribdlNEyh73lZBnjanNu_5SVJAcJfMC_89ZQVCaJj0KEFWIX8w [following]
# --2019-08-19 06:56:24--  https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?Ot-oKd58tap83Nx4_8xZdQ85VlamSAwHQIV13GTVfI9CmQK19VqIZobvbVZO0Ar091OVdcyJ-_TNEHG0Zts8dQDt_QkOHe7VwCmPhspHdTXgCybsnnCe7_KL4sY5fxM7f9SjP7am99tiA7hVJP6izlMMdJoRmMcfAQ-ZXiCeribdlNEyh73lZBnjanNu_5SVJAcJfMC_89ZQVCaJj0KEFWIX8w
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.221.58, 2606:2800:233:ef6:15dd:1ece:1d50:1e1
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.221.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1913589814 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.78G   131MB/s    in 13s
#
# 2019-08-19 06:56:37 (141 MB/s) - ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’ saved [1913589814/1913589814]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-8-0-local-ga2.
# (Reading database ... 136183 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb ...
# Unpacking cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Setting up cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Warning: The postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2
# Warning: seems to use apt-key (provided by apt) without depending on gnupg or gnupg2.
# Warning: This will BREAK in the future and should be fixed by the package maintainer(s).
# Note: Check first if apt-key functionality is needed at all - it probably isn't!
# Warning: apt-key should not be used in scripts (called from postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2)
# OK
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-license-10-1.
# (Reading database ... 136277 files and directories currently installed.)
# Preparing to unpack .../00-cuda-license-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-license-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-misc-headers-10-1.
# Preparing to unpack .../01-cuda-misc-headers-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-misc-headers-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvcc-10-1.
# Preparing to unpack .../02-cuda-nvcc-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvcc-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cuobjdump-10-1.
# Preparing to unpack .../03-cuda-cuobjdump-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cuobjdump-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvprune-10-1.
# Preparing to unpack .../04-cuda-nvprune-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvprune-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-compiler-10-1.
# Preparing to unpack .../05-cuda-compiler-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-compiler-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvdisasm-10-1.
# Preparing to unpack .../06-cuda-nvdisasm-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvdisasm-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-gdb-10-1.
# Preparing to unpack .../07-cuda-gdb-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-gdb-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvprof-10-1.
# Preparing to unpack .../08-cuda-nvprof-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvprof-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-sanitizer-api-10-1.
# Preparing to unpack .../09-cuda-sanitizer-api-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-sanitizer-api-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-memcheck-10-1.
# Preparing to unpack .../10-cuda-memcheck-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-memcheck-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cudart-10-1.
# Preparing to unpack .../11-cuda-cudart-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cudart-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-driver-dev-10-1.
# Preparing to unpack .../12-cuda-driver-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-driver-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cudart-dev-10-1.
# Preparing to unpack .../13-cuda-cudart-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cudart-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cupti-10-1.
# Preparing to unpack .../14-cuda-cupti-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cupti-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-gpu-library-advisor-10-1.
# Preparing to unpack .../15-cuda-gpu-library-advisor-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-gpu-library-advisor-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvtx-10-1.
# Preparing to unpack .../16-cuda-nvtx-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvtx-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-command-line-tools-10-1.
# Preparing to unpack .../17-cuda-command-line-tools-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-command-line-tools-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nsight-10-1.
# Preparing to unpack .../18-cuda-nsight-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nsight-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvvp-10-1.
# Preparing to unpack .../19-cuda-nvvp-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvvp-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvrtc-10-1.
# Preparing to unpack .../20-cuda-nvrtc-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvrtc-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-10-1.
# Preparing to unpack .../21-cuda-nvrtc-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cusolver-10-1.
# Preparing to unpack .../22-cuda-cusolver-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cusolver-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cusolver-dev-10-1.
# Preparing to unpack .../23-cuda-cusolver-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package libcublas10.
# Preparing to unpack .../24-libcublas10_10.2.1.243-1_amd64.deb ...
# Unpacking libcublas10 (10.2.1.243-1) ...
# Selecting previously unselected package libcublas-dev.
# Preparing to unpack .../25-libcublas-dev_10.2.1.243-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.1.243-1) ...
# Selecting previously unselected package cuda-cufft-10-1.
# Preparing to unpack .../26-cuda-cufft-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cufft-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cufft-dev-10-1.
# Preparing to unpack .../27-cuda-cufft-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cufft-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-curand-10-1.
# Preparing to unpack .../28-cuda-curand-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-curand-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-curand-dev-10-1.
# Preparing to unpack .../29-cuda-curand-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-curand-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cusparse-10-1.
# Preparing to unpack .../30-cuda-cusparse-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cusparse-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-cusparse-dev-10-1.
# Preparing to unpack .../31-cuda-cusparse-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-npp-10-1.
# Preparing to unpack .../32-cuda-npp-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-npp-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-npp-dev-10-1.
# Preparing to unpack .../33-cuda-npp-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-npp-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvml-dev-10-1.
# Preparing to unpack .../34-cuda-nvml-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvml-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvjpeg-10-1.
# Preparing to unpack .../35-cuda-nvjpeg-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvjpeg-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvjpeg-dev-10-1.
# Preparing to unpack .../36-cuda-nvjpeg-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvjpeg-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package nsight-compute-2019.4.0.
# Preparing to unpack .../37-nsight-compute-2019.4.0_2019.4.0.12-1_amd64.deb ...
# Unpacking nsight-compute-2019.4.0 (2019.4.0.12-1) ...
# Selecting previously unselected package cuda-nsight-compute-10-1.
# Preparing to unpack .../38-cuda-nsight-compute-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nsight-compute-10-1 (10.1.243-1) ...
# Selecting previously unselected package nsight-systems-2019.3.7.
# Preparing to unpack .../39-nsight-systems-2019.3.7_2019.3.7.5-3837e03_amd64.deb ...
# Unpacking nsight-systems-2019.3.7 (2019.3.7.5-3837e03) ...
# Selecting previously unselected package cuda-nsight-systems-10-1.
# Preparing to unpack .../40-cuda-nsight-systems-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nsight-systems-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvgraph-10-1.
# Preparing to unpack .../41-cuda-nvgraph-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvgraph-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-10-1.
# Preparing to unpack .../42-cuda-nvgraph-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-visual-tools-10-1.
# Preparing to unpack .../43-cuda-visual-tools-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-visual-tools-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-tools-10-1.
# Preparing to unpack .../44-cuda-tools-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-tools-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-samples-10-1.
# Preparing to unpack .../45-cuda-samples-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-samples-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-documentation-10-1.
# Preparing to unpack .../46-cuda-documentation-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-documentation-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-libraries-dev-10-1.
# Preparing to unpack .../47-cuda-libraries-dev-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-libraries-dev-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-toolkit-10-1.
# Preparing to unpack .../48-cuda-toolkit-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-toolkit-10-1 (10.1.243-1) ...
# Selecting previously unselected package libnvidia-common-430.
# Preparing to unpack .../49-libnvidia-common-430_430.40-0ubuntu0~gpu18.04.1_all.deb ...
# Unpacking libnvidia-common-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../50-libnvidia-common-418_430.40-0ubuntu0~gpu18.04.1_all.deb ...
# Unpacking libnvidia-common-418 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../51-nvidia-driver-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-driver-418 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../52-libnvidia-gl-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-gl-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../53-libnvidia-decode-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-decode-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../54-libnvidia-compute-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-compute-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-430:amd64.
# Preparing to unpack .../55-libnvidia-compute-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-compute-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package libnvidia-gl-430:amd64.
# Preparing to unpack .../56-libnvidia-gl-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-gl-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../57-nvidia-dkms-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Removing all DKMS Modules
# Done.
# Unpacking nvidia-dkms-418 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../58-nvidia-kernel-source-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-source-418 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-430.
# Preparing to unpack .../59-nvidia-kernel-source-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-source-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../60-nvidia-kernel-common-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-common-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-430.
# Preparing to unpack .../61-nvidia-kernel-common-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-common-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package nvidia-dkms-430.
# Preparing to unpack .../62-nvidia-dkms-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-dkms-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../63-nvidia-compute-utils-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Unpacking nvidia-compute-utils-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-430.
# Preparing to unpack .../64-nvidia-compute-utils-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-compute-utils-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package libnvidia-decode-430:amd64.
# Preparing to unpack .../65-libnvidia-decode-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-decode-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../66-libnvidia-encode-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-encode-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-430:amd64.
# Preparing to unpack .../67-libnvidia-encode-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-encode-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../68-nvidia-utils-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-utils-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-430.
# Preparing to unpack .../69-nvidia-utils-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-utils-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../70-xserver-xorg-video-nvidia-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Preparing to unpack .../71-libnvidia-cfg1-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-cfg1-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-430:amd64.
# Preparing to unpack .../72-libnvidia-cfg1-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-cfg1-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-430.
# Preparing to unpack .../73-xserver-xorg-video-nvidia-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../74-libnvidia-ifr1-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-ifr1-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package libnvidia-ifr1-430:amd64.
# Preparing to unpack .../75-libnvidia-ifr1-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-ifr1-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../76-libnvidia-fbc1-418_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-fbc1-418:amd64 (430.40-0ubuntu0~gpu18.04.1) over (418.67-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-430:amd64.
# Preparing to unpack .../77-libnvidia-fbc1-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking libnvidia-fbc1-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package nvidia-driver-430.
# Preparing to unpack .../78-nvidia-driver-430_430.40-0ubuntu0~gpu18.04.1_amd64.deb ...
# Unpacking nvidia-driver-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../79-cuda-drivers_418.87.00-1_amd64.deb ...
# Unpacking cuda-drivers (418.87.00-1) over (418.67-1) ...
# Selecting previously unselected package cuda-libraries-10-1.
# Preparing to unpack .../80-cuda-libraries-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-libraries-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-runtime-10-1.
# Preparing to unpack .../81-cuda-runtime-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-runtime-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-demo-suite-10-1.
# Preparing to unpack .../82-cuda-demo-suite-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-demo-suite-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda-10-1.
# Preparing to unpack .../83-cuda-10-1_10.1.243-1_amd64.deb ...
# Unpacking cuda-10-1 (10.1.243-1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../84-cuda_10.1.243-1_amd64.deb ...
# Unpacking cuda (10.1.243-1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../85-nvidia-prime_0.8.8.2_all.deb ...
# Unpacking nvidia-prime (0.8.8.2) ...
# Setting up nvidia-prime (0.8.8.2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up nsight-compute-2019.4.0 (2019.4.0.12-1) ...
# Setting up nvidia-kernel-common-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-kernel-common-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-common-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-license-10-1 (10.1.243-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-10.1/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-cusparse-10-1 (10.1.243-1) ...
# Setting up nsight-systems-2019.3.7 (2019.3.7.5-3837e03) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2019.3.7/Target-x86_64/x86_64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2019.3.7/Host-x86_64/nsight-sys to provide /usr/local/bin/nsight-sys (nsight-sys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2019.3.7/Host-x86_64/nsys-exporter to provide /usr/local/bin/nsys-exporter (nsys-exporter) in auto mode
# Setting up cuda-nvjpeg-10-1 (10.1.243-1) ...
# Setting up cuda-nsight-10-1 (10.1.243-1) ...
# Setting up cuda-nvdisasm-10-1 (10.1.243-1) ...
# Setting up cuda-nvml-dev-10-1 (10.1.243-1) ...
# Setting up cuda-sanitizer-api-10-1 (10.1.243-1) ...
# Setting up cuda-nvjpeg-dev-10-1 (10.1.243-1) ...
# Setting up cuda-cufft-10-1 (10.1.243-1) ...
# Setting up libnvidia-cfg1-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-nvprof-10-1 (10.1.243-1) ...
# Setting up cuda-nvrtc-10-1 (10.1.243-1) ...
# Setting up libcublas10 (10.2.1.243-1) ...
# Setting up libcublas-dev (10.2.1.243-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up cuda-npp-10-1 (10.1.243-1) ...
# Setting up libnvidia-compute-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-kernel-source-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-cufft-dev-10-1 (10.1.243-1) ...
# Setting up libnvidia-cfg1-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up cuda-nvvp-10-1 (10.1.243-1) ...
# Setting up cuda-driver-dev-10-1 (10.1.243-1) ...
# Setting up cuda-cuobjdump-10-1 (10.1.243-1) ...
# Setting up libnvidia-fbc1-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-nsight-systems-10-1 (10.1.243-1) ...
# Setting up cuda-gdb-10-1 (10.1.243-1) ...
# Setting up nvidia-dkms-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Loading new nvidia-430.40 DKMS files...
# It is likely that 4.14.79+ belongs to a chroot's host
# Building for 4.15.0-55-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-55-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-55-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-55-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-55-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-55-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up cuda-nsight-compute-10-1 (10.1.243-1) ...
# Setting up libnvidia-fbc1-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-cudart-10-1 (10.1.243-1) ...
# Setting up libnvidia-common-418 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-kernel-source-418 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-npp-dev-10-1 (10.1.243-1) ...
# Setting up cuda-cusolver-10-1 (10.1.243-1) ...
# Setting up cuda-misc-headers-10-1 (10.1.243-1) ...
# Setting up cuda-nvtx-10-1 (10.1.243-1) ...
# Setting up cuda-curand-10-1 (10.1.243-1) ...
# Setting up xserver-xorg-video-nvidia-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-decode-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-gl-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-utils-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-compute-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-cusparse-dev-10-1 (10.1.243-1) ...
# Setting up cuda-gpu-library-advisor-10-1 (10.1.243-1) ...
# Setting up cuda-nvgraph-10-1 (10.1.243-1) ...
# Setting up cuda-nvprune-10-1 (10.1.243-1) ...
# Setting up nvidia-utils-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-memcheck-10-1 (10.1.243-1) ...
# Setting up cuda-cudart-dev-10-1 (10.1.243-1) ...
# Setting up cuda-nvrtc-dev-10-1 (10.1.243-1) ...
# Setting up nvidia-compute-utils-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-curand-dev-10-1 (10.1.243-1) ...
# Setting up libnvidia-gl-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-compute-utils-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-encode-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-cusolver-dev-10-1 (10.1.243-1) ...
# Setting up libnvidia-ifr1-430:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-dkms-418 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-ifr1-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-nvgraph-dev-10-1 (10.1.243-1) ...
# Setting up libnvidia-encode-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up xserver-xorg-video-nvidia-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up libnvidia-decode-418:amd64 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-libraries-10-1 (10.1.243-1) ...
# Setting up cuda-nvcc-10-1 (10.1.243-1) ...
# Setting up nvidia-driver-430 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up nvidia-driver-418 (430.40-0ubuntu0~gpu18.04.1) ...
# Setting up cuda-compiler-10-1 (10.1.243-1) ...
# Setting up cuda-drivers (418.87.00-1) ...
# Setting up cuda-visual-tools-10-1 (10.1.243-1) ...
# Setting up cuda-libraries-dev-10-1 (10.1.243-1) ...
# Setting up cuda-samples-10-1 (10.1.243-1) ...
# Setting up cuda-cupti-10-1 (10.1.243-1) ...
# Setting up cuda-documentation-10-1 (10.1.243-1) ...
# Setting up cuda-runtime-10-1 (10.1.243-1) ...
# Setting up cuda-command-line-tools-10-1 (10.1.243-1) ...
# Setting up cuda-demo-suite-10-1 (10.1.243-1) ...
# Setting up cuda-tools-10-1 (10.1.243-1) ...
# Setting up cuda-toolkit-10-1 (10.1.243-1) ...
# Setting up cuda-10-1 (10.1.243-1) ...
# Setting up cuda (10.1.243-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Get:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Ign:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:7 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Hit:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:14 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Fetched 252 kB in 2s (127 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 5 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-cfg1-418 libnvidia-common-410 linux-headers-4.15.0-55
#   linux-headers-4.15.0-55-generic
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   linux-headers-4.15.0-58 linux-headers-4.15.0-58-generic
# The following packages have been kept back:
#   libcudnn7 libcudnn7-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   linux-headers-generic
# 1 upgraded, 2 newly installed, 0 to remove and 4 not upgraded.
# Need to get 12.1 MB of archives.
# After this operation, 88.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-58 all 4.15.0-58.64 [11.0 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-58-generic amd64 4.15.0-58.64 [1,148 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-generic amd64 4.15.0.58.60 [2,444 B]
# Fetched 12.1 MB in 0s (49.1 MB/s)
# Selecting previously unselected package linux-headers-4.15.0-58.
# (Reading database ... 149109 files and directories currently installed.)
# Preparing to unpack .../linux-headers-4.15.0-58_4.15.0-58.64_all.deb ...
# Unpacking linux-headers-4.15.0-58 (4.15.0-58.64) ...
# Selecting previously unselected package linux-headers-4.15.0-58-generic.
# Preparing to unpack .../linux-headers-4.15.0-58-generic_4.15.0-58.64_amd64.deb ...
# Unpacking linux-headers-4.15.0-58-generic (4.15.0-58.64) ...
# Preparing to unpack .../linux-headers-generic_4.15.0.58.60_amd64.deb ...
# Unpacking linux-headers-generic (4.15.0.58.60) over (4.15.0.55.57) ...
# Setting up linux-headers-4.15.0-58 (4.15.0-58.64) ...
# Setting up linux-headers-4.15.0-58-generic (4.15.0-58.64) ...
# /etc/kernel/header_postinst.d/dkms:
#  * dkms: running auto installation service for kernel 4.15.0-58-generic
#
# Kernel preparation unnecessary for this kernel.  Skipping...
#
# Building module:
# cleaning build area...(bad exit status: 2)
# unset ARCH; env NV_VERBOSE=1 'make' -j2 NV_EXCLUDE_BUILD_MODULES='' KERNEL_UNAME=4.15.0-58-generic IGNORE_XEN_PRESENCE=1 IGNORE_CC_MISMATCH=1 SYSSRC=/lib/modules/4.15.0-58-generic/build LD=/usr/bin/ld.bfd modules...............................
# cleaning build area...(bad exit status: 2)
#
# DKMS: build completed.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-58-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-58-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-58-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-58-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
#    ...done.
# Setting up linux-headers-generic (4.15.0.58.60) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-8-0' for regex 'cuda-8.0'
# Note, selecting 'libcuda-8.0-1' for regex 'cuda-8.0'
# The following packages were automatically installed and are no longer required:
#   libnvidia-cfg1-418 libnvidia-common-410 linux-headers-4.15.0-55
#   linux-headers-4.15.0-55-generic
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0
#   cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0
#   cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0
#   cuda-visual-tools-8-0
# The following NEW packages will be installed:
#   cuda-8-0 cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0
#   cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0
#   cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0
#   cuda-visual-tools-8-0
# 0 upgraded, 31 newly installed, 0 to remove and 4 not upgraded.
# Need to get 0 B/1,312 MB of archives.
# After this operation, 2,079 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-8-0-local-ga2  cuda-license-8-0 8.0.61-1 [27.6 kB]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  cuda-misc-headers-8-0 8.0.61-1 [1,077 kB]
# Get:3 file:/var/cuda-repo-8-0-local-ga2  cuda-core-8-0 8.0.61-1 [20.0 MB]
# Get:4 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-8-0 8.0.61-1 [135 kB]
# Get:5 file:/var/cuda-repo-8-0-local-ga2  cuda-driver-dev-8-0 8.0.61-1 [14.1 kB]
# Get:6 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-dev-8-0 8.0.61-1 [1,071 kB]
# Get:7 file:/var/cuda-repo-8-0-local-ga2  cuda-command-line-tools-8-0 8.0.61-1 [26.1 MB]
# Get:8 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-8-0 8.0.61-1 [9,585 kB]
# Get:9 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-dev-8-0 8.0.61-1 [10.8 kB]
# Get:10 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-8-0 8.0.61-1 [29.3 MB]
# Get:11 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-dev-8-0 8.0.61-1 [6,816 kB]
# Get:12 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-8-0 8.0.61-1 [27.2 MB]
# Get:13 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-dev-8-0 8.0.61-1 [57.4 MB]
# Get:14 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-8-0 8.0.61-1 [117 MB]
# Get:15 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-dev-8-0 8.0.61-1 [94.8 MB]
# Get:16 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-8-0 8.0.61-1 [43.7 MB]
# Get:17 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-dev-8-0 8.0.61-1 [67.7 MB]
# Get:18 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-8-0 8.0.61-1 [28.8 MB]
# Get:19 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-dev-8-0 8.0.61-1 [29.6 MB]
# Get:20 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-8-0 8.0.61-1 [157 MB]
# Get:21 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-dev-8-0 8.0.61-1 [82.3 MB]
# Get:22 file:/var/cuda-repo-8-0-local-ga2  cuda-samples-8-0 8.0.61-1 [101 MB]
# Get:23 file:/var/cuda-repo-8-0-local-ga2  cuda-documentation-8-0 8.0.61-1 [113 MB]
# Get:24 file:/var/cuda-repo-8-0-local-ga2  cuda-nvml-dev-8-0 8.0.61-1 [48.4 kB]
# Get:25 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-8-0 8.0.61-1 [2,948 kB]
# Get:26 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-dev-8-0 8.0.61-1 [3,028 kB]
# Get:27 file:/var/cuda-repo-8-0-local-ga2  cuda-visual-tools-8-0 8.0.61-1 [286 MB]
# Get:28 file:/var/cuda-repo-8-0-local-ga2  cuda-toolkit-8-0 8.0.61-1 [2,892 B]
# Get:29 file:/var/cuda-repo-8-0-local-ga2  cuda-runtime-8-0 8.0.61-1 [2,574 B]
# Get:30 file:/var/cuda-repo-8-0-local-ga2  cuda-demo-suite-8-0 8.0.61-1 [4,988 kB]
# Get:31 file:/var/cuda-repo-8-0-local-ga2  cuda-8-0 8.0.61-1 [2,556 B]
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-license-8-0.
# (Reading database ... 178372 files and directories currently installed.)
# Preparing to unpack .../00-cuda-license-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-license-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-misc-headers-8-0.
# Preparing to unpack .../01-cuda-misc-headers-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-misc-headers-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-core-8-0.
# Preparing to unpack .../02-cuda-core-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-core-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-8-0.
# Preparing to unpack .../03-cuda-cudart-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-driver-dev-8-0.
# Preparing to unpack .../04-cuda-driver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-driver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-dev-8-0.
# Preparing to unpack .../05-cuda-cudart-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-command-line-tools-8-0.
# Preparing to unpack .../06-cuda-command-line-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-command-line-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-8-0.
# Preparing to unpack .../07-cuda-nvrtc-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-8-0.
# Preparing to unpack .../08-cuda-nvrtc-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-8-0.
# Preparing to unpack .../09-cuda-cusolver-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-dev-8-0.
# Preparing to unpack .../10-cuda-cusolver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-8-0.
# Preparing to unpack .../11-cuda-cublas-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-dev-8-0.
# Preparing to unpack .../12-cuda-cublas-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-8-0.
# Preparing to unpack .../13-cuda-cufft-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-dev-8-0.
# Preparing to unpack .../14-cuda-cufft-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-8-0.
# Preparing to unpack .../15-cuda-curand-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-dev-8-0.
# Preparing to unpack .../16-cuda-curand-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-8-0.
# Preparing to unpack .../17-cuda-cusparse-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-dev-8-0.
# Preparing to unpack .../18-cuda-cusparse-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-8-0.
# Preparing to unpack .../19-cuda-npp-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-dev-8-0.
# Preparing to unpack .../20-cuda-npp-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-samples-8-0.
# Preparing to unpack .../21-cuda-samples-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-samples-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-documentation-8-0.
# Preparing to unpack .../22-cuda-documentation-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-documentation-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvml-dev-8-0.
# Preparing to unpack .../23-cuda-nvml-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvml-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-8-0.
# Preparing to unpack .../24-cuda-nvgraph-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-8-0.
# Preparing to unpack .../25-cuda-nvgraph-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-visual-tools-8-0.
# Preparing to unpack .../26-cuda-visual-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-visual-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-toolkit-8-0.
# Preparing to unpack .../27-cuda-toolkit-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-toolkit-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-runtime-8-0.
# Preparing to unpack .../28-cuda-runtime-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-runtime-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-demo-suite-8-0.
# Preparing to unpack .../29-cuda-demo-suite-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-demo-suite-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-8-0.
# Preparing to unpack .../30-cuda-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-8-0 (8.0.61-1) ...
# Setting up cuda-license-8-0 (8.0.61-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-8.0/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-nvgraph-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-8-0 (8.0.61-1) ...
# Setting up cuda-npp-8-0 (8.0.61-1) ...
# Setting up cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-8-0 (8.0.61-1) ...
# Setting up cuda-driver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-8-0 (8.0.61-1) ...
# Setting up cuda-nvml-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-dev-8-0 (8.0.61-1) ...
# Setting up cuda-misc-headers-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Setting up cuda-curand-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-core-8-0 (8.0.61-1) ...
# Setting up cuda-curand-dev-8-0 (8.0.61-1) ...
# Setting up cuda-npp-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-dev-8-0 (8.0.61-1) ...
# Setting up cuda-runtime-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Setting up cuda-command-line-tools-8-0 (8.0.61-1) ...
# Setting up cuda-demo-suite-8-0 (8.0.61-1) ...
# Setting up cuda-samples-8-0 (8.0.61-1) ...
# Setting up cuda-visual-tools-8-0 (8.0.61-1) ...
# Setting up cuda-documentation-8-0 (8.0.61-1) ...
# Setting up cuda-toolkit-8-0 (8.0.61-1) ...
# Setting up cuda-8-0 (8.0.61-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# /device:GPU:0
# 'sup!'
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
ls
# Out:
# cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb  drive/
# darknet/                                               sample_data/

# %%
# %cd darknet
# !make
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: At global scope:
# ./src/image_opencv.cpp:420:14: warning: ‘float get_pixel(image, int, int, int)’ defined but not used [-Wunused-function]
#  static float get_pixel(image m, int x, int y, int c)
#               ^
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:475:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2037:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^
# ./src/gemm.c:2036:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘get_cuda_stream’:
# ./src/dark_cuda.c:120:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^
# ./src/dark_cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/dark_cuda.c:141:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1019:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^
# ./src/convolutional_layer.c: In function ‘assisted_excitation_forward’:
# ./src/convolutional_layer.c:1101:17: warning: unused variable ‘epoch’ [-Wunused-variable]
#      const float epoch = (float)(*state.net.seen) / state.net.train_images_num;
#                  ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:68:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:138:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:881:19: warning: unused variable ‘scale’ [-Wunused-variable]
#              float scale = rand_precalc_random(.25, 2, r_scale); // unused currently
#                    ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:562:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1007:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:52:16: warning: unused variable ‘names’ [-Wunused-variable]
#          char **names = get_labels_custom(name_list, &names_size);
#                 ^
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1046:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^
# ./src/detector.c:1045:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:58:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:65:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:92:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:101:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# In file included from ./src/scale_channels_layer.c:5:0:
# ./src/scale_channels_layer.c: In function ‘make_scale_channels_layer’:
# ./src/scale_channels_layer.c:16:14: warning: suggest parentheses around comparison in operand of ‘&’ [-Wparentheses]
#      assert(w == 1 & h == 1);
#               ^
# ./src/scale_channels_layer.c:16:14: warning: suggest parentheses around comparison in operand of ‘&’ [-Wparentheses]
#      assert(w == 1 & h == 1);
#               ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/sam_layer.c -o obj/sam_layer.o
# In file included from ./src/sam_layer.c:5:0:
# ./src/sam_layer.c: In function ‘make_sam_layer’:
# ./src/sam_layer.c:21:16: warning: suggest parentheses around comparison in operand of ‘&’ [-Wparentheses]
#      assert(l.w == l.out_w & l.h == l.out_h);
#                 ^
# ./src/sam_layer.c:21:16: warning: suggest parentheses around comparison in operand of ‘&’ [-Wparentheses]
#      assert(l.w == l.out_w & l.h == l.out_h);
#                 ^
# ./src/sam_layer.c: In function ‘forward_sam_layer’:
# ./src/sam_layer.c:63:9: warning: unused variable ‘channel_size’ [-Wunused-variable]
#      int channel_size = 1;
#          ^
# ./src/sam_layer.c: In function ‘backward_sam_layer’:
# ./src/sam_layer.c:82:9: warning: unused variable ‘channel_size’ [-Wunused-variable]
#      int channel_size = 1;
#          ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(18): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(39): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(18): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(39): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(18): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(39): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(18): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(39): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(18): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(39): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(18): warning: variable "iteration_num" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(39): warning: variable "iteration_num" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lstdc++

# %%
# !ls
#Now, let's see if everything works by running it on a test image
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# 3rdparty	darknet			include		       scripts
# appveyor.yml	DarknetConfig.cmake.in	json_mjpeg_streams.sh  src
# backup		darknet.py		LICENSE		       test.txt
# build		darknet_video.py	__MACOSX	       train.txt
# build.ps1	data			Makefile	       video_v2.sh
# build.sh	data_for_colab		net_cam_v3.sh	       video_yolov3.sh
# cfg		data_for_colab.zip	obj		       yolov3.weights
# cmake		image_yolov2.sh		README.md
# CMakeLists.txt	image_yolov3.sh		results
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv    255       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 255 0.088 BF
#   82 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   83 route  79
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv    255       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 255 0.177 BF
#   94 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   95 route  91
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv    255       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 255 0.353 BF
#  106 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.864
#  Allocate additional workspace_size = 49.84 MB
# Loading weights from yolov3.weights...
#  seen 64
# Done!
# data/person.jpg: Predicted in 275.800000 milli-seconds.
# dog: 99%
# person: 100%
# horse: 100%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:26887): Gtk-WARNING **: 07:10:05.038: cannot open display:

# %%
#Let's define some functions that will let us show images, and upload and 
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
imShow('predictions.jpg')

# %%
ls
# Out:
# 3rdparty/               darknet_video.py        obj/
# appveyor.yml            data/                   predictions.jpg
# backup/                 data_for_colab/         README.md
# build/                  data_for_colab.zip      results/
# build.ps1*              image_yolov2.sh*        scripts/
# build.sh*               image_yolov3.sh*        src/
# cfg/                    include/                test.txt
# cmake/                  json_mjpeg_streams.sh*  train.txt
# CMakeLists.txt          LICENSE                 video_v2.sh*
# darknet*                __MACOSX/               video_yolov3.sh*
# DarknetConfig.cmake.in  Makefile                yolov3.weights
# darknet.py              net_cam_v3.sh*

# %%
# !./darknet detector train data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny.conv.15 -dont_show
# Out:
# yolov3-tiny-obj
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max               2 x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max               2 x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max               2 x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max               2 x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max               2 x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max               2 x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   16 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   23 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 24.92 MB
# Loading weights
# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov3.sh*        README.md
# appveyor.yml  darknet*                include/                results/
# backup/       DarknetConfig.cmake.in  json_mjpeg_streams.sh*  scripts/
# build/        darknet.py              LICENSE                 src/
# build.ps1*    darknet_video.py        __MACOSX/               test.txt
# build.sh*     data/                   Makefile                train.txt
# cfg/          data_for_colab/         net_cam_v3.sh*          video_v2.sh*
# chart.png     data_for_colab.zip      obj/                    video_yolov3.sh*
# cmake/        image_yolov2.sh*        predictions.jpg         yolov3.weights

# %%
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
#      <input type="file" id="files-d6576207-8b56-4888-84ba-8411abb2e96d" name="files[]" multiple disabled />
#      <output id="result-d6576207-8b56-4888-84ba-8411abb2e96d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.jpg to image.jpg
# saved file image.jpg

# %%
# !./darknet detector test data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_1000.weights image.jpg -i 0 -thresh 0.5
# Out:
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max               2 x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max               2 x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max               2 x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max               2 x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max               2 x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max               2 x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   16 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   23 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 24.92 MB
# Loading weights from backup/yolov3-tiny-obj_1000.weights...
#  seen 64
# Done!
# image.jpg: Predicted in 181.844000 milli-seconds.
# Unable to init server: Could not connect: Connection refused
#
# (predictions:33113): Gtk-WARNING **: 08:21:29.293: cannot open display:

# %%
imShow('predictions.jpg')

# %%
cd ..
# Out:
# /content

# %%
cp drive/'My Drive'/helmet/bike1.mp4 /content/darknet

# %%
cd darknet
# Out:
# /content/darknet

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov3.sh*        results/
# appveyor.yml  CMakeSettings.json      include/                scripts/
# backup/       darknet*                json_mjpeg_streams.sh*  src/
# bike.mp4      DarknetConfig.cmake.in  LICENSE                 test.jpg
# build/        darknet.py              __MACOSX/               test.txt
# build.ps1*    darknet_video.py        Makefile                train.txt
# build.sh*     data/                   net_cam_v3.sh*          video_v2.sh*
# cfg/          data_for_colab/         obj/                    video_yolov3.sh*
# chart.png     data_for_colab.zip      predictions.jpg
# cmake/        image_yolov2.sh*        README.md

# %%
# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_1000.weights  -dont_show bike1.mp4 -i 0 -out_filename veout.avi
# Out:
# Demo
# layer     filters    size              input                output
#    0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16 0.150 BF
#    1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16 0.003 BF
#    2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32 0.399 BF
#    3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32 0.001 BF
#    4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64 0.399 BF
#    5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64 0.001 BF
#    6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128 0.399 BF
#    7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128 0.000 BF
#    8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256 0.399 BF
#    9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256 0.000 BF
#   10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   11 max          2 x 2 / 1    13 x  13 x 512   ->    13 x  13 x 512 0.000 BF
#   12 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   13 conv    256  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 256 0.089 BF
#   14 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   15 conv     18  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x  18 0.003 BF
#   16 yolo
#   17 route  13
#   18 conv    128  1 x 1 / 1    13 x  13 x 256   ->    13 x  13 x 128 0.011 BF
#   19 upsample            2x    13 x  13 x 128   ->    26 x  26 x 128
#   20 route  19 8
#   21 conv    256  3 x 3 / 1    26 x  26 x 384   ->    26 x  26 x 256 1.196 BF
#   22 conv     18  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x  18 0.006 BF
#   23 yolo
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 24.92 MB
# Loading weights from backup/yolov3-tiny-obj_1000.weights...
#  seen 64
# Done!
# video file: bike1.mp4
# Video stream: 1280 x 720
#
# FPS:0.0
# Objects:
#
#
# FPS:0.0
# Objects:
#
# Helmet: 97%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 94%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:32.5
# Objects:
#
# Helmet: 95%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 91%
# Helmet: 89%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 95%
# Helmet: 85%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 94%
# Helmet: 81%
# Helmet: 67%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 88%
# Helmet: 69%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 93%
# Helmet: 88%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:31.0
# Objects:
#
# Helmet: 92%
# Helmet: 90%
# Helmet: 40%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 95%
# Helmet: 92%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:31.2
# Objects:
#
# Helmet: 95%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 98%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 91%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 92%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:29.4
# Objects:
#
# Helmet: 95%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 94%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:31.3
# Objects:
#
# Helmet: 95%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 98%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 99%
# Helmet: 92%
#
#  cvWriteFrame
#
# FPS:32.7
# Objects:
#
# Helmet: 99%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 99%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 98%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:32.5
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:30.2
# Objects:
#
# Helmet: 99%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:31.1
# Objects:
#
# Helmet: 99%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 99%
# Helmet: 78%
#
#  cvWriteFrame
#
# FPS:33.2
# Objects:
#
# Helmet: 99%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:32.7
# Objects:
#
# Helmet: 99%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:33.9
# Objects:
#
# Helmet: 89%
# Helmet: 88%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 86%
# Helmet: 81%
# Helmet: 72%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 90%
# Helmet: 77%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 94%
# Helmet: 81%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 97%
# Helmet: 88%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 95%
# Helmet: 74%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 98%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:33.2
# Objects:
#
# Helmet: 98%
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 99%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:32.8
# Objects:
#
# Helmet: 99%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:36.2
# Objects:
#
# Helmet: 100%
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 100%
# Helmet: 63%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:28.6
# Objects:
#
# Helmet: 100%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 100%
# Helmet: 67%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:31.2
# Objects:
#
# Helmet: 100%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 100%
# Helmet: 48%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:30.5
# Objects:
#
# Helmet: 100%
# Helmet: 58%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:31.9
# Objects:
#
# Helmet: 100%
# Helmet: 48%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:31.9
# Objects:
#
# Helmet: 100%
# Helmet: 58%
# Helmet: 34%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:28.0
# Objects:
#
# Helmet: 100%
# Helmet: 60%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 100%
# Helmet: 54%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:31.9
# Objects:
#
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:53.2
# Objects:
#
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
#
#  cvWriteFrame
#
# FPS:53.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:33.9
# Objects:
#
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:33.2
# Objects:
#
# Helmet: 34%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:44.1
# Objects:
#
# Helmet: 32%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 36%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 27%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:37.2
# Objects:
#
# Helmet: 62%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:32.0
# Objects:
#
# Helmet: 58%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 41%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 57%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:29.5
# Objects:
#
# Helmet: 69%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:52.1
# Objects:
#
# Helmet: 61%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:54.5
# Objects:
#
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:41.5
# Objects:
#
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:31.6
# Objects:
#
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:51.8
# Objects:
#
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:33.2
# Objects:
#
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:28.9
# Objects:
#
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:42.4
# Objects:
#
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 30%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 38%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:33.1
# Objects:
#
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:41.8
# Objects:
#
# Helmet: 53%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:25.1
# Objects:
#
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:58.1
# Objects:
#
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:32.3
# Objects:
#
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 60%
# Helmet: 55%
# Helmet: 47%
# Helmet: 45%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:56.2
# Objects:
#
# Helmet: 73%
# Helmet: 65%
# Helmet: 31%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 75%
# Helmet: 66%
# Helmet: 65%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 69%
# Helmet: 44%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 96%
# Helmet: 66%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 94%
# Helmet: 61%
# Helmet: 53%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 98%
# Helmet: 51%
# Helmet: 45%
# Helmet: 37%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 98%
# Helmet: 52%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 94%
# Helmet: 74%
# Helmet: 37%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 94%
# Helmet: 68%
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
# Helmet: 90%
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
# Helmet: 97%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:53.4
# Objects:
#
# Helmet: 96%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:33.9
# Objects:
#
# Helmet: 95%
# Helmet: 48%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
# Helmet: 97%
# Helmet: 58%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 89%
# Helmet: 60%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:32.8
# Objects:
#
# Helmet: 92%
# Helmet: 33%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
# Helmet: 85%
# Helmet: 47%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 70%
# Helmet: 61%
# Helmet: 42%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:32.9
# Objects:
#
# Helmet: 69%
# Helmet: 47%
# Helmet: 43%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 68%
# Helmet: 53%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 83%
# Helmet: 52%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 76%
# Helmet: 49%
# Helmet: 35%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 84%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:41.8
# Objects:
#
# Helmet: 90%
# Helmet: 53%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:36.7
# Objects:
#
# Helmet: 88%
# Helmet: 67%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 72%
# Helmet: 49%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 95%
# Helmet: 75%
# Helmet: 39%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:39.9
# Objects:
#
# Helmet: 88%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:31.7
# Objects:
#
# Helmet: 86%
# Helmet: 74%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:41.6
# Objects:
#
# Helmet: 94%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:32.2
# Objects:
#
# Helmet: 97%
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
# Helmet: 98%
# Helmet: 34%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 99%
# Helmet: 51%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 98%
# Helmet: 55%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 97%
# Helmet: 62%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:27.6
# Objects:
#
# Helmet: 94%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 99%
# Helmet: 51%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 97%
# Helmet: 45%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 97%
# Helmet: 53%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 98%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 92%
#
#  cvWriteFrame
#
# FPS:42.6
# Objects:
#
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 99%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 99%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:31.4
# Objects:
#
# Helmet: 98%
# Helmet: 37%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
# Helmet: 99%
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 99%
# Helmet: 60%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:42.4
# Objects:
#
# Helmet: 99%
# Helmet: 61%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:33.0
# Objects:
#
# Helmet: 97%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 98%
# Helmet: 63%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 99%
# Helmet: 62%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
# Helmet: 80%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 84%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:41.4
# Objects:
#
# Helmet: 81%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 89%
# Helmet: 63%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 92%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
# Helmet: 96%
# Helmet: 66%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 93%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 95%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:32.8
# Objects:
#
# Helmet: 92%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 97%
# Helmet: 90%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 99%
# Helmet: 88%
#
#  cvWriteFrame
#
# FPS:32.2
# Objects:
#
# Helmet: 98%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 100%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 99%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 98%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 98%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:42.1
# Objects:
#
# Helmet: 98%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
# Helmet: 98%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 99%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 99%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 99%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 100%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 100%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:36.8
# Objects:
#
# Helmet: 99%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:54.9
# Objects:
#
# Helmet: 99%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 99%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 99%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 98%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:39.9
# Objects:
#
# Helmet: 97%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:30.9
# Objects:
#
# Helmet: 98%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 94%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 97%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 98%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 99%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 99%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 99%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:27.4
# Objects:
#
# Helmet: 97%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 95%
# Helmet: 90%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 96%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:33.7
# Objects:
#
# Helmet: 94%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:41.4
# Objects:
#
# Helmet: 94%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:33.1
# Objects:
#
# Helmet: 96%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
# Helmet: 95%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 97%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:33.7
# Objects:
#
# Helmet: 98%
# Helmet: 39%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:33.7
# Objects:
#
# Helmet: 97%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:40.6
# Objects:
#
# Helmet: 94%
# Helmet: 46%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:41.5
# Objects:
#
# Helmet: 75%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 70%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 72%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:36.6
# Objects:
#
# Helmet: 82%
# Helmet: 72%
#
#  cvWriteFrame
#
# FPS:43.1
# Objects:
#
# Helmet: 95%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 99%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 99%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 99%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:31.7
# Objects:
#
# Helmet: 100%
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 100%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:33.1
# Objects:
#
# Helmet: 100%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 100%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:41.4
# Objects:
#
# Helmet: 100%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:32.7
# Objects:
#
# Helmet: 98%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:43.3
# Objects:
#
# Helmet: 98%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:56.1
# Objects:
#
# Helmet: 99%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:42.9
# Objects:
#
# Helmet: 95%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:36.2
# Objects:
#
# Helmet: 98%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 96%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 99%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 99%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 99%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:51.8
# Objects:
#
# Helmet: 99%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:40.2
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:32.5
# Objects:
#
# Helmet: 98%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:41.9
# Objects:
#
# Helmet: 98%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:32.4
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 99%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:46.5
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:29.1
# Objects:
#
# Helmet: 100%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 99%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 100%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 100%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:41.3
# Objects:
#
# Helmet: 100%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 100%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:39.7
# Objects:
#
# Helmet: 100%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
# Helmet: 99%
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:31.4
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:30.6
# Objects:
#
# Helmet: 100%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:46.7
# Objects:
#
# Helmet: 99%
# Helmet: 92%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 99%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 100%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 100%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 100%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:39.1
# Objects:
#
# Helmet: 99%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:32.9
# Objects:
#
# Helmet: 99%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:31.9
# Objects:
#
# Helmet: 100%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:29.2
# Objects:
#
# Helmet: 100%
# Helmet: 86%
#
#  cvWriteFrame
#
# FPS:33.7
# Objects:
#
# Helmet: 100%
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 99%
# Helmet: 81%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 100%
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 100%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
# Helmet: 100%
# Helmet: 93%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 100%
# Helmet: 90%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 100%
# Helmet: 92%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 100%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:42.0
# Objects:
#
# Helmet: 99%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:50.0
# Objects:
#
# Helmet: 100%
# Helmet: 79%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 99%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:30.4
# Objects:
#
# Helmet: 100%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:39.7
# Objects:
#
# Helmet: 100%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 100%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 100%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:52.2
# Objects:
#
# Helmet: 100%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 100%
# Helmet: 70%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 100%
# Helmet: 64%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 100%
# Helmet: 58%
#
#  cvWriteFrame
#
# FPS:42.9
# Objects:
#
# Helmet: 100%
# Helmet: 81%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 100%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:36.7
# Objects:
#
# Helmet: 100%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:47.8
# Objects:
#
# Helmet: 99%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 100%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 99%
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 98%
# Helmet: 96%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:30.3
# Objects:
#
# Helmet: 94%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 98%
# Helmet: 89%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 99%
# Helmet: 86%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
# Helmet: 98%
# Helmet: 79%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:28.8
# Objects:
#
# Helmet: 94%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 97%
# Helmet: 78%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 90%
# Helmet: 81%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 91%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 79%
# Helmet: 62%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 88%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 92%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 97%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 99%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:43.3
# Objects:
#
# Helmet: 99%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:46.3
# Objects:
#
# Helmet: 100%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:41.9
# Objects:
#
# Helmet: 100%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:32.8
# Objects:
#
# Helmet: 100%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 100%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:29.6
# Objects:
#
# Helmet: 100%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 100%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:54.5
# Objects:
#
# Helmet: 100%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 98%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 71%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 74%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:40.8
# Objects:
#
# Helmet: 53%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 64%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 68%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:40.6
# Objects:
#
# Helmet: 67%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 80%
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 70%
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 70%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 81%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 79%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 72%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 63%
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 80%
# Helmet: 45%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 85%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 90%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
# Helmet: 91%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 85%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:39.1
# Objects:
#
# Helmet: 87%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:51.1
# Objects:
#
# Helmet: 85%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 84%
# Helmet: 63%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 86%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:40.7
# Objects:
#
# Helmet: 79%
# Helmet: 74%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 88%
# Helmet: 76%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 85%
# Helmet: 77%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 74%
# Helmet: 65%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 73%
# Helmet: 65%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 71%
# Helmet: 58%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 72%
# Helmet: 56%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
# Helmet: 74%
# Helmet: 72%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 78%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 83%
# Helmet: 58%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:31.8
# Objects:
#
# Helmet: 83%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 81%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:32.1
# Objects:
#
# Helmet: 83%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
# Helmet: 81%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:29.2
# Objects:
#
# Helmet: 85%
# Helmet: 39%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 79%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:37.2
# Objects:
#
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 57%
# Helmet: 42%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 73%
# Helmet: 46%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:37.2
# Objects:
#
# Helmet: 62%
# Helmet: 56%
# Helmet: 39%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 54%
# Helmet: 51%
# Helmet: 32%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:39.1
# Objects:
#
# Helmet: 55%
# Helmet: 45%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 55%
# Helmet: 43%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 62%
# Helmet: 53%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:40.2
# Objects:
#
# Helmet: 68%
# Helmet: 64%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 59%
# Helmet: 58%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 63%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 73%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 71%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:37.2
# Objects:
#
# Helmet: 73%
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:40.0
# Objects:
#
# Helmet: 56%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 38%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 53%
# Helmet: 46%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:32.6
# Objects:
#
# Helmet: 60%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 63%
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 68%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 72%
# Helmet: 64%
# Helmet: 33%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:40.2
# Objects:
#
# Helmet: 84%
# Helmet: 70%
# Helmet: 49%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
# Helmet: 82%
# Helmet: 75%
# Helmet: 43%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 86%
# Helmet: 78%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 87%
# Helmet: 73%
# Helmet: 35%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 90%
# Helmet: 77%
# Helmet: 37%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 84%
# Helmet: 63%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:41.9
# Objects:
#
# Helmet: 89%
# Helmet: 56%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 88%
# Helmet: 57%
# Helmet: 57%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:36.6
# Objects:
#
# Helmet: 92%
# Helmet: 77%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 89%
# Helmet: 58%
# Helmet: 48%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 83%
# Helmet: 67%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 92%
# Helmet: 67%
# Helmet: 42%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 87%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:27.4
# Objects:
#
# Helmet: 91%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 82%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 81%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:36.2
# Objects:
#
# Helmet: 75%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 81%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 78%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:31.9
# Objects:
#
# Helmet: 75%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 70%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
# Helmet: 69%
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 68%
# Helmet: 58%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 68%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 52%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
# Helmet: 60%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 61%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 46%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 39%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 35%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 40%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 38%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:42.6
# Objects:
#
# Helmet: 45%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:42.7
# Objects:
#
# Helmet: 42%
# Helmet: 35%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:47.0
# Objects:
#
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:37.2
# Objects:
#
# Helmet: 45%
# Helmet: 44%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 32%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
# Helmet: 48%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 74%
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:32.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 53%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:42.4
# Objects:
#
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:32.4
# Objects:
#
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:33.7
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:31.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:42.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:28.9
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:39.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:31.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:32.4
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:43.5
# Objects:
#
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 41%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:46.7
# Objects:
#
# Helmet: 35%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 42%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 39%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:31.3
# Objects:
#
# Helmet: 27%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:31.3
# Objects:
#
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:42.3
# Objects:
#
# Helmet: 50%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 43%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:33.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:48.2
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:31.1
# Objects:
#
# Helmet: 36%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:39.6
# Objects:
#
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:43.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:40.6
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:42.6
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:48.8
# Objects:
#
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:40.6
# Objects:
#
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:31.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:39.1
# Objects:
#
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:30.1
# Objects:
#
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:39.1
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:28.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
#
#  cvWriteFrame
#
# FPS:32.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:42.9
# Objects:
#
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.7
# Objects:
#
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:29.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 95%
# Helmet: 72%
# Helmet: 64%
#
#  cvWriteFrame
#
# FPS:42.2
# Objects:
#
# Helmet: 96%
# Helmet: 59%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 99%
# Helmet: 66%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 99%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:36.6
# Objects:
#
# Helmet: 99%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:42.3
# Objects:
#
# Helmet: 100%
# Helmet: 90%
#
#  cvWriteFrame
#
# FPS:40.8
# Objects:
#
# Helmet: 99%
# Helmet: 79%
# Helmet: 35%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 98%
# Helmet: 67%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:40.5
# Objects:
#
# Helmet: 95%
# Helmet: 73%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 91%
# Helmet: 73%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 96%
# Helmet: 91%
# Helmet: 49%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
# Helmet: 97%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 98%
# Helmet: 91%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 98%
# Helmet: 79%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 97%
# Helmet: 90%
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
# Helmet: 98%
# Helmet: 82%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 99%
# Helmet: 88%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:26.6
# Objects:
#
# Helmet: 94%
# Helmet: 88%
# Helmet: 76%
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
# Helmet: 93%
# Helmet: 87%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 84%
# Helmet: 83%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 90%
# Helmet: 61%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 94%
# Helmet: 89%
# Helmet: 79%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 94%
# Helmet: 93%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 92%
# Helmet: 90%
# Helmet: 75%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 92%
# Helmet: 91%
# Helmet: 61%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 91%
# Helmet: 89%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:41.5
# Objects:
#
# Helmet: 94%
# Helmet: 93%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 96%
# Helmet: 82%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 98%
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:42.2
# Objects:
#
# Helmet: 99%
# Helmet: 86%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 99%
# Helmet: 90%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:43.0
# Objects:
#
# Helmet: 99%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:37.2
# Objects:
#
# Helmet: 99%
# Helmet: 86%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 99%
# Helmet: 61%
# Helmet: 58%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 97%
# Helmet: 72%
# Helmet: 62%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 91%
# Helmet: 88%
# Helmet: 33%
# Helmet: 29%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 85%
# Helmet: 77%
# Helmet: 53%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 82%
# Helmet: 81%
# Helmet: 37%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 91%
# Helmet: 67%
# Helmet: 52%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 85%
# Helmet: 73%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 98%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:37.5
# Objects:
#
# Helmet: 99%
# Helmet: 84%
# Helmet: 66%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 97%
# Helmet: 87%
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:28.0
# Objects:
#
# Helmet: 98%
# Helmet: 78%
# Helmet: 77%
#
#  cvWriteFrame
#
# FPS:40.6
# Objects:
#
# Helmet: 97%
# Helmet: 86%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 97%
# Helmet: 97%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 98%
# Helmet: 93%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 91%
# Helmet: 89%
# Helmet: 78%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 92%
# Helmet: 79%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 81%
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
# Helmet: 91%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 88%
# Helmet: 53%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
# Helmet: 80%
# Helmet: 32%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 64%
# Helmet: 41%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 76%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:42.8
# Objects:
#
# Helmet: 97%
# Helmet: 43%
# Helmet: 40%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 97%
# Helmet: 51%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 97%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 98%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 97%
# Helmet: 41%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:44.1
# Objects:
#
# Helmet: 96%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 94%
# Helmet: 40%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:45.4
# Objects:
#
# Helmet: 93%
# Helmet: 49%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:51.7
# Objects:
#
# Helmet: 97%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
# Helmet: 89%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:32.3
# Objects:
#
# Helmet: 90%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:32.5
# Objects:
#
# Helmet: 97%
# Helmet: 33%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:31.4
# Objects:
#
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 89%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 90%
#
#  cvWriteFrame
#
# FPS:42.2
# Objects:
#
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:33.9
# Objects:
#
# Helmet: 93%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 94%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 97%
# Helmet: 44%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:37.5
# Objects:
#
# Helmet: 99%
# Helmet: 77%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:30.6
# Objects:
#
# Helmet: 98%
# Helmet: 89%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:42.5
# Objects:
#
# Helmet: 99%
# Helmet: 70%
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 98%
# Helmet: 67%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 98%
# Helmet: 68%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
# Helmet: 97%
# Helmet: 75%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 96%
# Helmet: 59%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 92%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 89%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
# Helmet: 92%
# Helmet: 48%
# Helmet: 27%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:42.5
# Objects:
#
# Helmet: 74%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 78%
# Helmet: 60%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:42.9
# Objects:
#
# Helmet: 79%
# Helmet: 67%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 77%
# Helmet: 66%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 73%
# Helmet: 63%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:27.8
# Objects:
#
# Helmet: 77%
# Helmet: 54%
# Helmet: 44%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 68%
# Helmet: 67%
# Helmet: 43%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 72%
# Helmet: 65%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 60%
# Helmet: 41%
# Helmet: 37%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 70%
# Helmet: 35%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 74%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:33.1
# Objects:
#
# Helmet: 75%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
# Helmet: 70%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:33.3
# Objects:
#
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 72%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:42.5
# Objects:
#
# Helmet: 70%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:31.2
# Objects:
#
# Helmet: 57%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 61%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 65%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 73%
# Helmet: 61%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 48%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:43.0
# Objects:
#
# Helmet: 71%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 58%
# Helmet: 40%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 78%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:42.4
# Objects:
#
# Helmet: 63%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 57%
# Helmet: 39%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:33.1
# Objects:
#
# Helmet: 59%
# Helmet: 47%
# Helmet: 44%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 58%
# Helmet: 49%
# Helmet: 38%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 59%
# Helmet: 48%
# Helmet: 46%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 79%
# Helmet: 77%
# Helmet: 41%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 88%
# Helmet: 81%
# Helmet: 44%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 87%
# Helmet: 76%
# Helmet: 62%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 91%
# Helmet: 62%
# Helmet: 61%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
# Helmet: 76%
# Helmet: 66%
# Helmet: 59%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 75%
# Helmet: 60%
# Helmet: 51%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 80%
# Helmet: 51%
# Helmet: 38%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 59%
# Helmet: 31%
# Helmet: 31%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:48.4
# Objects:
#
# Helmet: 59%
# Helmet: 32%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 40%
# Helmet: 37%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 50%
# Helmet: 50%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 71%
# Helmet: 69%
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:31.8
# Objects:
#
# Helmet: 68%
# Helmet: 65%
# Helmet: 60%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:48.6
# Objects:
#
# Helmet: 67%
# Helmet: 53%
# Helmet: 52%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 62%
# Helmet: 42%
# Helmet: 33%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 50%
# Helmet: 46%
# Helmet: 41%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:50.3
# Objects:
#
# Helmet: 65%
# Helmet: 54%
# Helmet: 34%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 69%
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:42.1
# Objects:
#
# Helmet: 73%
# Helmet: 34%
# Helmet: 31%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:42.2
# Objects:
#
# Helmet: 71%
# Helmet: 69%
# Helmet: 58%
# Helmet: 34%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:33.2
# Objects:
#
# Helmet: 85%
# Helmet: 82%
# Helmet: 42%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:40.7
# Objects:
#
# Helmet: 86%
# Helmet: 76%
# Helmet: 28%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:32.4
# Objects:
#
# Helmet: 85%
# Helmet: 81%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 91%
# Helmet: 77%
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
# Helmet: 90%
# Helmet: 70%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 96%
# Helmet: 93%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 91%
# Helmet: 87%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 95%
# Helmet: 93%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 89%
# Helmet: 73%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 87%
# Helmet: 86%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 81%
# Helmet: 64%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 89%
# Helmet: 69%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:41.8
# Objects:
#
# Helmet: 86%
# Helmet: 83%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:42.3
# Objects:
#
# Helmet: 90%
# Helmet: 80%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 96%
# Helmet: 69%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:31.3
# Objects:
#
# Helmet: 85%
# Helmet: 58%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:41.4
# Objects:
#
# Helmet: 95%
# Helmet: 54%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:33.9
# Objects:
#
# Helmet: 98%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 98%
# Helmet: 52%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 94%
# Helmet: 77%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 96%
# Helmet: 82%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 91%
# Helmet: 89%
#
#  cvWriteFrame
#
# FPS:27.0
# Objects:
#
# Helmet: 97%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:37.5
# Objects:
#
# Helmet: 98%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
# Helmet: 97%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 93%
# Helmet: 90%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 93%
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 92%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
# Helmet: 79%
# Helmet: 66%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 85%
# Helmet: 75%
# Helmet: 46%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 93%
# Helmet: 75%
# Helmet: 47%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 92%
# Helmet: 80%
# Helmet: 39%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 95%
# Helmet: 80%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:32.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.0
# Objects:
#
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:36.4
# Objects:
#
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:32.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:32.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:43.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:33.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.2
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:43.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:43.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:39.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:32.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.4
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:30.1
# Objects:
#
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
#
#  cvWriteFrame
#
# ...
#
# Helmet: 69%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 60%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:56.9
# Objects:
#
# Helmet: 66%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 66%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:40.7
# Objects:
#
# Helmet: 64%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 71%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:36.2
# Objects:
#
# Helmet: 90%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
# Helmet: 96%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
# Helmet: 95%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:41.6
# Objects:
#
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 95%
# Helmet: 41%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 91%
# Helmet: 40%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:43.8
# Objects:
#
# Helmet: 97%
# Helmet: 32%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:45.7
# Objects:
#
# Helmet: 97%
# Helmet: 28%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 95%
# Helmet: 63%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 98%
# Helmet: 66%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 97%
# Helmet: 39%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:39.6
# Objects:
#
# Helmet: 92%
# Helmet: 47%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:39.6
# Objects:
#
# Helmet: 92%
# Helmet: 37%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 91%
# Helmet: 70%
# Helmet: 50%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:32.5
# Objects:
#
# Helmet: 92%
# Helmet: 68%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:43.3
# Objects:
#
# Helmet: 87%
# Helmet: 65%
# Helmet: 57%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 76%
# Helmet: 74%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 75%
# Helmet: 72%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 90%
# Helmet: 69%
# Helmet: 58%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:33.4
# Objects:
#
# Helmet: 92%
# Helmet: 73%
# Helmet: 33%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 97%
# Helmet: 69%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 80%
# Helmet: 72%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:34.9
# Objects:
#
# Helmet: 86%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 76%
# Helmet: 59%
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:35.9
# Objects:
#
# Helmet: 73%
# Helmet: 40%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 83%
# Helmet: 48%
# Helmet: 45%
#
#  cvWriteFrame
#
# FPS:49.2
# Objects:
#
# Helmet: 73%
# Helmet: 58%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:50.9
# Objects:
#
# Helmet: 85%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:32.1
# Objects:
#
# Helmet: 80%
# Helmet: 67%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 74%
# Helmet: 58%
# Helmet: 29%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:32.3
# Objects:
#
# Helmet: 67%
# Helmet: 47%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 93%
# Helmet: 58%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 95%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:42.1
# Objects:
#
# Helmet: 93%
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 96%
# Helmet: 70%
#
#  cvWriteFrame
#
# FPS:32.7
# Objects:
#
# Helmet: 93%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:32.8
# Objects:
#
# Helmet: 89%
# Helmet: 76%
#
#  cvWriteFrame
#
# FPS:26.9
# Objects:
#
# Helmet: 88%
# Helmet: 69%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 95%
# Helmet: 66%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 97%
# Helmet: 76%
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
# Helmet: 99%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
# Helmet: 97%
# Helmet: 49%
# Helmet: 35%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:33.0
# Objects:
#
# Helmet: 98%
# Helmet: 60%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 99%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:32.4
# Objects:
#
# Helmet: 99%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:29.0
# Objects:
#
# Helmet: 99%
#
#  cvWriteFrame
#
# FPS:36.0
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:27.5
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:38.8
# Objects:
#
# Helmet: 94%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:47.6
# Objects:
#
# Helmet: 94%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:43.3
# Objects:
#
# Helmet: 75%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:38.7
# Objects:
#
# Helmet: 94%
# Helmet: 33%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:39.6
# Objects:
#
# Helmet: 99%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 99%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
# Helmet: 99%
# Helmet: 59%
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 98%
# Helmet: 56%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 98%
# Helmet: 64%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 97%
# Helmet: 66%
#
#  cvWriteFrame
#
# FPS:42.2
# Objects:
#
# Helmet: 97%
# Helmet: 71%
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 98%
# Helmet: 66%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 98%
# Helmet: 75%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 98%
# Helmet: 74%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 98%
# Helmet: 76%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 97%
# Helmet: 71%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 80%
# Helmet: 79%
# Helmet: 63%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 92%
# Helmet: 78%
# Helmet: 75%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 85%
# Helmet: 63%
# Helmet: 61%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:43.5
# Objects:
#
# Helmet: 73%
# Helmet: 50%
# Helmet: 39%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 82%
# Helmet: 70%
# Helmet: 40%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:42.2
# Objects:
#
# Helmet: 83%
# Helmet: 77%
# Helmet: 25%
# Helmet: 25%
#
#  cvWriteFrame
#
# FPS:38.1
# Objects:
#
# Helmet: 92%
# Helmet: 63%
# Helmet: 54%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 90%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:31.6
# Objects:
#
# Helmet: 92%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 90%
# Helmet: 59%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:43.6
# Objects:
#
# Helmet: 97%
# Helmet: 30%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 98%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 98%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:29.6
# Objects:
#
# Helmet: 97%
#
#  cvWriteFrame
#
# FPS:39.9
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 98%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 98%
# Helmet: 45%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 95%
# Helmet: 57%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 96%
# Helmet: 64%
# Helmet: 28%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 92%
# Helmet: 60%
# Helmet: 38%
#
#  cvWriteFrame
#
# FPS:27.5
# Objects:
#
# Helmet: 92%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:39.1
# Objects:
#
# Helmet: 87%
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 60%
# Helmet: 44%
#
#  cvWriteFrame
#
# FPS:36.8
# Objects:
#
# Helmet: 80%
# Helmet: 29%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 59%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 82%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:38.2
# Objects:
#
# Helmet: 76%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:34.4
# Objects:
#
# Helmet: 85%
# Helmet: 71%
#
#  cvWriteFrame
#
# FPS:34.1
# Objects:
#
# Helmet: 77%
# Helmet: 61%
# Helmet: 52%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:36.3
# Objects:
#
# Helmet: 81%
# Helmet: 63%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 76%
# Helmet: 52%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:42.1
# Objects:
#
# Helmet: 61%
# Helmet: 57%
# Helmet: 50%
#
#  cvWriteFrame
#
# FPS:40.8
# Objects:
#
# Helmet: 54%
# Helmet: 45%
# Helmet: 42%
# Helmet: 40%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:35.5
# Objects:
#
# Helmet: 79%
# Helmet: 48%
# Helmet: 47%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:44.2
# Objects:
#
# Helmet: 71%
# Helmet: 57%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:41.3
# Objects:
#
# Helmet: 90%
# Helmet: 75%
# Helmet: 46%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 95%
# Helmet: 61%
# Helmet: 46%
#
#  cvWriteFrame
#
# FPS:35.6
# Objects:
#
# Helmet: 99%
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:35.1
# Objects:
#
# Helmet: 98%
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:36.6
# Objects:
#
# Helmet: 98%
# Helmet: 36%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:36.4
# Objects:
#
# Helmet: 98%
# Helmet: 32%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 96%
# Helmet: 43%
# Helmet: 31%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:41.1
# Objects:
#
# Helmet: 98%
# Helmet: 39%
# Helmet: 39%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:40.8
# Objects:
#
# Helmet: 99%
# Helmet: 45%
# Helmet: 28%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 99%
# Helmet: 62%
#
#  cvWriteFrame
#
# FPS:39.7
# Objects:
#
# Helmet: 99%
# Helmet: 65%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 99%
# Helmet: 88%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:40.3
# Objects:
#
# Helmet: 99%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:35.8
# Objects:
#
# Helmet: 99%
# Helmet: 94%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:37.8
# Objects:
#
# Helmet: 98%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:32.9
# Objects:
#
# Helmet: 99%
# Helmet: 86%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 96%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:37.9
# Objects:
#
# Helmet: 99%
# Helmet: 96%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 98%
# Helmet: 94%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 99%
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:42.8
# Objects:
#
# Helmet: 98%
# Helmet: 95%
#
#  cvWriteFrame
#
# FPS:38.5
# Objects:
#
# Helmet: 99%
# Helmet: 91%
# Helmet: 43%
#
#  cvWriteFrame
#
# FPS:38.0
# Objects:
#
# Helmet: 99%
# Helmet: 97%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 98%
# Helmet: 84%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 97%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:40.1
# Objects:
#
# Helmet: 97%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:34.7
# Objects:
#
# Helmet: 98%
# Helmet: 87%
#
#  cvWriteFrame
#
# FPS:44.1
# Objects:
#
# Helmet: 93%
# Helmet: 78%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 90%
# Helmet: 74%
#
#  cvWriteFrame
#
# FPS:40.0
# Objects:
#
# Helmet: 92%
# Helmet: 77%
#
#  cvWriteFrame
#
# FPS:37.6
# Objects:
#
# Helmet: 92%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 87%
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 85%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:47.9
# Objects:
#
# Helmet: 87%
# Helmet: 79%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 69%
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:50.7
# Objects:
#
# Helmet: 90%
# Helmet: 35%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 94%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:40.9
# Objects:
#
# Helmet: 98%
# Helmet: 53%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 98%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 96%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 99%
# Helmet: 61%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 100%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 99%
# Helmet: 40%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 99%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:42.9
# Objects:
#
# Helmet: 98%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 99%
# Helmet: 58%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 98%
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:36.9
# Objects:
#
# Helmet: 99%
# Helmet: 63%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 99%
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:35.0
# Objects:
#
# Helmet: 98%
# Helmet: 48%
#
#  cvWriteFrame
#
# FPS:36.1
# Objects:
#
# Helmet: 98%
# Helmet: 65%
#
#  cvWriteFrame
#
# FPS:33.6
# Objects:
#
# Helmet: 98%
# Helmet: 70%
#
#  cvWriteFrame
#
# FPS:33.0
# Objects:
#
# Helmet: 98%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:33.5
# Objects:
#
# Helmet: 98%
# Helmet: 89%
#
#  cvWriteFrame
#
# FPS:37.5
# Objects:
#
# Helmet: 96%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 92%
# Helmet: 88%
#
#  cvWriteFrame
#
# FPS:39.9
# Objects:
#
# Helmet: 95%
# Helmet: 74%
#
#  cvWriteFrame
#
# FPS:42.5
# Objects:
#
# Helmet: 98%
# Helmet: 59%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 97%
# Helmet: 63%
#
#  cvWriteFrame
#
# FPS:36.6
# Objects:
#
# Helmet: 85%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 87%
# Helmet: 67%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:43.3
# Objects:
#
# Helmet: 96%
# Helmet: 81%
#
#  cvWriteFrame
#
# FPS:32.8
# Objects:
#
# Helmet: 93%
# Helmet: 76%
#
#  cvWriteFrame
#
# FPS:34.6
# Objects:
#
# Helmet: 93%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:41.5
# Objects:
#
# Helmet: 91%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:47.5
# Objects:
#
# Helmet: 90%
# Helmet: 85%
#
#  cvWriteFrame
#
# FPS:38.9
# Objects:
#
# Helmet: 90%
# Helmet: 72%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 96%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:41.3
# Objects:
#
# Helmet: 90%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:42.0
# Objects:
#
# Helmet: 66%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 72%
#
#  cvWriteFrame
#
# FPS:39.3
# Objects:
#
# Helmet: 76%
# Helmet: 60%
#
#  cvWriteFrame
#
# FPS:39.2
# Objects:
#
# Helmet: 83%
# Helmet: 68%
#
#  cvWriteFrame
#
# FPS:38.6
# Objects:
#
# Helmet: 94%
# Helmet: 80%
#
#  cvWriteFrame
#
# FPS:42.0
# Objects:
#
# Helmet: 74%
# Helmet: 67%
#
#  cvWriteFrame
#
# FPS:36.2
# Objects:
#
# Helmet: 83%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 93%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 98%
# Helmet: 78%
#
#  cvWriteFrame
#
# FPS:41.8
# Objects:
#
# Helmet: 99%
# Helmet: 88%
#
#  cvWriteFrame
#
# FPS:38.4
# Objects:
#
# Helmet: 98%
# Helmet: 76%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 96%
# Helmet: 84%
#
#  cvWriteFrame
#
# FPS:47.7
# Objects:
#
# Helmet: 98%
# Helmet: 82%
#
#  cvWriteFrame
#
# FPS:36.8
# Objects:
#
# Helmet: 98%
# Helmet: 92%
#
#  cvWriteFrame
#
# FPS:35.3
# Objects:
#
# Helmet: 97%
# Helmet: 89%
#
#  cvWriteFrame
#
# FPS:40.2
# Objects:
#
# Helmet: 93%
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:36.4
# Objects:
#
# Helmet: 98%
# Helmet: 75%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 98%
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:40.7
# Objects:
#
# Helmet: 98%
# Helmet: 33%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.3
# Objects:
#
# Helmet: 91%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:31.2
# Objects:
#
# Helmet: 94%
# Helmet: 30%
#
#  cvWriteFrame
#
# FPS:42.0
# Objects:
#
# Helmet: 92%
# Helmet: 73%
#
#  cvWriteFrame
#
# FPS:39.8
# Objects:
#
# Helmet: 85%
# Helmet: 32%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 81%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:43.5
# Objects:
#
# Helmet: 86%
#
#  cvWriteFrame
#
# FPS:34.8
# Objects:
#
# Helmet: 87%
# Helmet: 35%
# Helmet: 27%
#
#  cvWriteFrame
#
# FPS:38.3
# Objects:
#
# Helmet: 91%
#
#  cvWriteFrame
#
# FPS:39.0
# Objects:
#
# Helmet: 75%
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 72%
# Helmet: 42%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:40.6
# Objects:
#
# Helmet: 77%
# Helmet: 51%
#
#  cvWriteFrame
#
# FPS:42.7
# Objects:
#
# Helmet: 62%
# Helmet: 59%
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:37.0
# Objects:
#
# Helmet: 83%
#
#  cvWriteFrame
#
# FPS:36.8
# Objects:
#
# Helmet: 91%
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:27.5
# Objects:
#
# Helmet: 95%
# Helmet: 41%
#
#  cvWriteFrame
#
# FPS:37.7
# Objects:
#
# Helmet: 92%
# Helmet: 51%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:41.4
# Objects:
#
# Helmet: 89%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:41.6
# Objects:
#
# Helmet: 87%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:42.7
# Objects:
#
# Helmet: 65%
# Helmet: 49%
#
#  cvWriteFrame
#
# FPS:33.8
# Objects:
#
# Helmet: 54%
# Helmet: 42%
#
#  cvWriteFrame
#
# FPS:34.5
# Objects:
#
# Helmet: 34%
#
#  cvWriteFrame
#
# FPS:35.2
# Objects:
#
# Helmet: 52%
#
#  cvWriteFrame
#
# FPS:36.5
# Objects:
#
# Helmet: 55%
#
#  cvWriteFrame
#
# FPS:33.2
# Objects:
#
# Helmet: 54%
#
#  cvWriteFrame
#
# FPS:40.2
# Objects:
#
# Helmet: 77%
#
#  cvWriteFrame
#
# FPS:35.4
# Objects:
#
# Helmet: 76%
#
#  cvWriteFrame
#
# FPS:37.3
# Objects:
#
# Helmet: 77%
# Helmet: 39%
#
#  cvWriteFrame
#
# FPS:39.7
# Objects:
#
# Helmet: 64%
# Helmet: 36%
#
#  cvWriteFrame
#
# FPS:35.7
# Objects:
#
# Helmet: 63%
# Helmet: 56%
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
# Helmet: 69%
#
#  cvWriteFrame
#
# FPS:41.0
# Objects:
#
# Helmet: 57%
#
#  cvWriteFrame
#
# FPS:36.7
# Objects:
#
# Helmet: 40%
#
#  cvWriteFrame
#
# FPS:40.7
# Objects:
#
# Helmet: 32%
#
#  cvWriteFrame
#
# FPS:41.2
# Objects:
#
# Helmet: 26%
#
#  cvWriteFrame
#
# FPS:34.0
# Objects:
#
# Helmet: 31%
# Helmet: 29%
#
#  cvWriteFrame
#
# FPS:40.4
# Objects:
#
# Helmet: 32%
# Helmet: 28%
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:43.2
# Objects:
#
# Helmet: 33%
#
#  cvWriteFrame
#
# FPS:39.5
# Objects:
#
#
#  cvWriteFrame
#
# FPS:41.7
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:37.5
# Objects:
#
# Helmet: 31%
#
#  cvWriteFrame
#
# FPS:52.9
# Objects:
#
# Helmet: 37%
#
#  cvWriteFrame
#
# FPS:37.1
# Objects:
#
# Helmet: 37%
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
# output_video_writer closed.

# %%
download('veout.avi')

# %%
# !./darknet detector calc_anchors Dataset/obj.data -num_of_clusters 5 -width 416 -height 416
# Out:
#  num_of_clusters = 5, width = 416, height = 416
#  read labels from 237 images
#  loaded 	 image: 30 	 box: 30
#
# Wrong label: /content/darknet/Dataset/nfpa/pos-130.txt - j = 0, x = 0.508333, y = 0.473333, width = 1.010000, height = 0.613333
#  loaded 	 image: 73 	 box: 74
#
# Wrong label: /content/darknet/Dataset/nfpa/pos-173.txt - j = 2, x = 0.440625, y = 0.969555, width = 0.000000, height = 0.000000
#  loaded 	 image: 236 	 box: 298Can't open label file. (This can be normal only if you use MSCOCO):
#
#  all loaded.
#
#  calculating k-means++ ...
#
#  iterations = 13
#
#
#  avg IoU = 69.58 %
#
# Saving anchors to the file: anchors.txt
# anchors =   8, 17,  57, 75, 160,154, 199,284, 354,364
# ^C
